# %%
# which attack level to add noise
noise_type = 7
# how much noise to add: 0.00, 0.05, 0.10, 0.20, 0.50
noise_percent = 0.50

# %%
import re
import os
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae_trainer import VAETrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')

# %%
seed = 29
torch.manual_seed(seed)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class SensorDataset():
    def __init__(self, data: np.array):
        self.x = self.np2tensor(data)
        
    @staticmethod
    def np2tensor(x):
        return torch.tensor(x, dtype=torch.float32)
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx]

# %%
latent_dims = 118
batch_size = 16
epochs = 1000

# %%
data_filename = 'data.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)
train_size = int(T * 0.8)
lr = 1e-1
scheduler = True
es_patience = 10

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Original Sensor Signal')
plt.show()

# %%
# read attack noise
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  5.96it/s]

# %%
noise_size = int(T * noise_percent)
norm_operation_win = 50
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for _type in noise_to_add_from:
    noise_id = random.sample(range(int(2 * T / 3)), 1)
    noises.append(Z_noise[_type][noise_id])
random.shuffle(noises)
if len(noises) > 0:
    noises = np.concatenate(noises, axis=0)
    # add noises to original sensor data Z
    Z[noise_time,:] = noises

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Noisy Sensor Signal')
plt.show()

# %%
Z_train, Z_test = Z[:train_size], Z[train_size:]
training = SensorDataset(Z_train)
test = SensorDataset(Z_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = VAETrainer(latent_dim=latent_dims, lr=lr, 
                     lr_scheduler=scheduler, es_patience=es_patience,
                     checkpoint_name=f'vae_{int(noise_percent*100)}%.pt', 
                     seed=seed)

# %%
summary(trainer.vae, (1, 358))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [1, 358]                  --
# ├─VariationalEncoder: 1-1                [1, 118]                  --
# │    └─Linear: 2-1                       [1, 236]                  84,724
# │    └─BatchNorm1d: 2-2                  [1, 236]                  472
# │    └─Linear: 2-3                       [1, 118]                  27,966
# │    └─Linear: 2-4                       [1, 118]                  14,042
# │    └─Linear: 2-5                       [1, 118]                  14,042
# ├─Decoder: 1-2                           [1, 358]                  --
# │    └─Linear: 2-6                       [1, 236]                  28,084
# │    └─BatchNorm1d: 2-7                  [1, 236]                  472
# │    └─Linear: 2-8                       [1, 358]                  84,846
# ==========================================================================================
# Total params: 254,648
# Trainable params: 254,648
# Non-trainable params: 0
# Total mult-adds (M): 0.25
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ==========================================================================================

# %%
vae, mse, kl, val_mse, val_kl = trainer.train(train_dl, test_dl, epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 1.4996], [KL: 1.1477], [Val_MSE: 0.1775], [Val_KL: 0.3771],
# Validation loss decreased (inf --> 0.177543).  Saving model ...
# Epoch 2/1000: [MSE: 0.1389], [KL: 0.3726], [Val_MSE: 0.1165], [Val_KL: 0.3817],
# Validation loss decreased (0.177543 --> 0.116475).  Saving model ...
# Epoch 3/1000: [MSE: 0.1225], [KL: 0.3727], [Val_MSE: 0.1132], [Val_KL: 0.3657],
# Validation loss decreased (0.116475 --> 0.113196).  Saving model ...
# Epoch 4/1000: [MSE: 0.1092], [KL: 0.3728], [Val_MSE: 0.1137], [Val_KL: 0.3691],
# EarlyStopping counter: 1 out of 10
# Epoch 5/1000: [MSE: 0.1100], [KL: 0.3710], [Val_MSE: 0.0924], [Val_KL: 0.3676],
# Validation loss decreased (0.113196 --> 0.092386).  Saving model ...
# Epoch 6/1000: [MSE: 0.0986], [KL: 0.3691], [Val_MSE: 0.1180], [Val_KL: 0.3666],
# EarlyStopping counter: 1 out of 10
# Epoch 7/1000: [MSE: 0.0933], [KL: 0.3693], [Val_MSE: 0.0905], [Val_KL: 0.3640],
# Validation loss decreased (0.092386 --> 0.090466).  Saving model ...
# Epoch 8/1000: [MSE: 0.0932], [KL: 0.3678], [Val_MSE: 0.1110], [Val_KL: 0.3613],
# EarlyStopping counter: 1 out of 10
# Epoch 9/1000: [MSE: 0.0959], [KL: 0.3680], [Val_MSE: 0.0893], [Val_KL: 0.3683],
# Validation loss decreased (0.090466 --> 0.089251).  Saving model ...
# Epoch 10/1000: [MSE: 0.0995], [KL: 0.3694], [Val_MSE: 0.1380], [Val_KL: 0.3654],
# EarlyStopping counter: 1 out of 10
# Epoch 11/1000: [MSE: 0.0988], [KL: 0.3697], [Val_MSE: 0.1019], [Val_KL: 0.3651],
# EarlyStopping counter: 2 out of 10
# Epoch 12/1000: [MSE: 0.0936], [KL: 0.3683], [Val_MSE: 0.1230], [Val_KL: 0.3655],
# EarlyStopping counter: 3 out of 10
# Epoch 13/1000: [MSE: 0.0950], [KL: 0.3688], [Val_MSE: 0.0896], [Val_KL: 0.3687],
# EarlyStopping counter: 4 out of 10
# Epoch 14/1000: [MSE: 0.0989], [KL: 0.3688], [Val_MSE: 0.0961], [Val_KL: 0.3667],
# EarlyStopping counter: 5 out of 10
# Epoch 15/1000: [MSE: 0.1043], [KL: 0.3693], [Val_MSE: 0.0845], [Val_KL: 0.3683],
# Validation loss decreased (0.089251 --> 0.084454).  Saving model ...
# Epoch 16/1000: [MSE: 0.0972], [KL: 0.3679], [Val_MSE: 0.1238], [Val_KL: 0.3702],
# EarlyStopping counter: 1 out of 10
# Epoch 17/1000: [MSE: 0.0951], [KL: 0.3700], [Val_MSE: 0.0895], [Val_KL: 0.3632],
# EarlyStopping counter: 2 out of 10
# Epoch 18/1000: [MSE: 0.0972], [KL: 0.3685], [Val_MSE: 0.0829], [Val_KL: 0.3654],
# Validation loss decreased (0.084454 --> 0.082917).  Saving model ...
# Epoch 19/1000: [MSE: 0.0943], [KL: 0.3687], [Val_MSE: 0.0898], [Val_KL: 0.3651],
# EarlyStopping counter: 1 out of 10
# Epoch 20/1000: [MSE: 0.0911], [KL: 0.3688], [Val_MSE: 0.1098], [Val_KL: 0.3631],
# EarlyStopping counter: 2 out of 10
# Epoch 21/1000: [MSE: 0.0930], [KL: 0.3681], [Val_MSE: 0.0771], [Val_KL: 0.3721],
# Validation loss decreased (0.082917 --> 0.077070).  Saving model ...
# Epoch 22/1000: [MSE: 0.0930], [KL: 0.3688], [Val_MSE: 0.0772], [Val_KL: 0.3680],
# EarlyStopping counter: 1 out of 10
# Epoch 23/1000: [MSE: 0.0975], [KL: 0.3692], [Val_MSE: 0.0825], [Val_KL: 0.3691],
# EarlyStopping counter: 2 out of 10
# Epoch 24/1000: [MSE: 0.0910], [KL: 0.3691], [Val_MSE: 0.0764], [Val_KL: 0.3684],
# Validation loss decreased (0.077070 --> 0.076409).  Saving model ...
# Epoch 25/1000: [MSE: 0.0892], [KL: 0.3694], [Val_MSE: 0.0758], [Val_KL: 0.3705],
# Validation loss decreased (0.076409 --> 0.075752).  Saving model ...
# Epoch 26/1000: [MSE: 0.0895], [KL: 0.3697], [Val_MSE: 0.0824], [Val_KL: 0.3681],
# EarlyStopping counter: 1 out of 10
# Epoch 27/1000: [MSE: 0.0897], [KL: 0.3693], [Val_MSE: 0.0722], [Val_KL: 0.3679],
# Validation loss decreased (0.075752 --> 0.072230).  Saving model ...
# Epoch 28/1000: [MSE: 0.0931], [KL: 0.3698], [Val_MSE: 0.1128], [Val_KL: 0.3711],
# EarlyStopping counter: 1 out of 10
# Epoch 29/1000: [MSE: 0.0939], [KL: 0.3694], [Val_MSE: 0.0750], [Val_KL: 0.3719],
# EarlyStopping counter: 2 out of 10
# Epoch 30/1000: [MSE: 0.0873], [KL: 0.3696], [Val_MSE: 0.1058], [Val_KL: 0.3639],
# EarlyStopping counter: 3 out of 10
# Epoch 31/1000: [MSE: 0.0872], [KL: 0.3694], [Val_MSE: 0.0719], [Val_KL: 0.3660],
# Validation loss decreased (0.072230 --> 0.071926).  Saving model ...
# Epoch 32/1000: [MSE: 0.0877], [KL: 0.3702], [Val_MSE: 0.0778], [Val_KL: 0.3681],
# EarlyStopping counter: 1 out of 10
# Epoch 33/1000: [MSE: 0.0884], [KL: 0.3688], [Val_MSE: 0.0722], [Val_KL: 0.3686],
# EarlyStopping counter: 2 out of 10
# Epoch 34/1000: [MSE: 0.0825], [KL: 0.3684], [Val_MSE: 0.0869], [Val_KL: 0.3678],
# EarlyStopping counter: 3 out of 10
# Epoch 35/1000: [MSE: 0.0857], [KL: 0.3692], [Val_MSE: 0.0827], [Val_KL: 0.3659],
# EarlyStopping counter: 4 out of 10
# Epoch 36/1000: [MSE: 0.0862], [KL: 0.3688], [Val_MSE: 0.0842], [Val_KL: 0.3705],
# EarlyStopping counter: 5 out of 10
# Epoch 37/1000: [MSE: 0.0910], [KL: 0.3698], [Val_MSE: 0.0737], [Val_KL: 0.3698],
# EarlyStopping counter: 6 out of 10
# Epoch 38/1000: [MSE: 0.0870], [KL: 0.3692], [Val_MSE: 0.0772], [Val_KL: 0.3670],
# EarlyStopping counter: 7 out of 10
# Epoch 39/1000: [MSE: 0.0731], [KL: 0.3673], [Val_MSE: 0.0605], [Val_KL: 0.3667],
# Validation loss decreased (0.071926 --> 0.060451).  Saving model ...
# Epoch 40/1000: [MSE: 0.0703], [KL: 0.3674], [Val_MSE: 0.0582], [Val_KL: 0.3678],
# Validation loss decreased (0.060451 --> 0.058216).  Saving model ...
# Epoch 41/1000: [MSE: 0.0738], [KL: 0.3672], [Val_MSE: 0.0604], [Val_KL: 0.3661],
# EarlyStopping counter: 1 out of 10
# Epoch 42/1000: [MSE: 0.0690], [KL: 0.3677], [Val_MSE: 0.0611], [Val_KL: 0.3665],
# EarlyStopping counter: 2 out of 10
# Epoch 43/1000: [MSE: 0.0713], [KL: 0.3671], [Val_MSE: 0.0570], [Val_KL: 0.3673],
# Validation loss decreased (0.058216 --> 0.057002).  Saving model ...
# Epoch 44/1000: [MSE: 0.0720], [KL: 0.3673], [Val_MSE: 0.0604], [Val_KL: 0.3668],
# EarlyStopping counter: 1 out of 10
# Epoch 45/1000: [MSE: 0.0731], [KL: 0.3672], [Val_MSE: 0.0603], [Val_KL: 0.3653],
# EarlyStopping counter: 2 out of 10
# Epoch 46/1000: [MSE: 0.0717], [KL: 0.3670], [Val_MSE: 0.0605], [Val_KL: 0.3660],
# EarlyStopping counter: 3 out of 10
# Epoch 47/1000: [MSE: 0.0717], [KL: 0.3674], [Val_MSE: 0.0639], [Val_KL: 0.3662],
# EarlyStopping counter: 4 out of 10
# Epoch 48/1000: [MSE: 0.0726], [KL: 0.3675], [Val_MSE: 0.0627], [Val_KL: 0.3695],
# EarlyStopping counter: 5 out of 10
# Epoch 49/1000: [MSE: 0.0717], [KL: 0.3674], [Val_MSE: 0.0618], [Val_KL: 0.3672],
# EarlyStopping counter: 6 out of 10
# Epoch 50/1000: [MSE: 0.0699], [KL: 0.3669], [Val_MSE: 0.0577], [Val_KL: 0.3670],
# EarlyStopping counter: 7 out of 10
# Epoch 51/1000: [MSE: 0.0676], [KL: 0.3669], [Val_MSE: 0.0570], [Val_KL: 0.3666],
# Validation loss decreased (0.057002 --> 0.056998).  Saving model ...
# Epoch 52/1000: [MSE: 0.0677], [KL: 0.3669], [Val_MSE: 0.0570], [Val_KL: 0.3663],
# Validation loss decreased (0.056998 --> 0.056993).  Saving model ...
# Epoch 53/1000: [MSE: 0.0666], [KL: 0.3666], [Val_MSE: 0.0563], [Val_KL: 0.3658],
# Validation loss decreased (0.056993 --> 0.056313).  Saving model ...
# Epoch 54/1000: [MSE: 0.0678], [KL: 0.3670], [Val_MSE: 0.0565], [Val_KL: 0.3670],
# EarlyStopping counter: 1 out of 10
# Epoch 55/1000: [MSE: 0.0682], [KL: 0.3667], [Val_MSE: 0.0608], [Val_KL: 0.3651],
# EarlyStopping counter: 2 out of 10
# Epoch 56/1000: [MSE: 0.0663], [KL: 0.3671], [Val_MSE: 0.0557], [Val_KL: 0.3672],
# Validation loss decreased (0.056313 --> 0.055659).  Saving model ...
# Epoch 57/1000: [MSE: 0.0699], [KL: 0.3670], [Val_MSE: 0.0545], [Val_KL: 0.3665],
# Validation loss decreased (0.055659 --> 0.054470).  Saving model ...
# Epoch 58/1000: [MSE: 0.0706], [KL: 0.3669], [Val_MSE: 0.0600], [Val_KL: 0.3660],
# EarlyStopping counter: 1 out of 10
# Epoch 59/1000: [MSE: 0.0679], [KL: 0.3670], [Val_MSE: 0.0550], [Val_KL: 0.3662],
# EarlyStopping counter: 2 out of 10
# Epoch 60/1000: [MSE: 0.0662], [KL: 0.3671], [Val_MSE: 0.0548], [Val_KL: 0.3663],
# EarlyStopping counter: 3 out of 10
# Epoch 61/1000: [MSE: 0.0676], [KL: 0.3668], [Val_MSE: 0.0561], [Val_KL: 0.3659],
# EarlyStopping counter: 4 out of 10
# Epoch 62/1000: [MSE: 0.0686], [KL: 0.3668], [Val_MSE: 0.0562], [Val_KL: 0.3664],
# EarlyStopping counter: 5 out of 10
# Epoch 63/1000: [MSE: 0.0686], [KL: 0.3670], [Val_MSE: 0.0569], [Val_KL: 0.3665],
# EarlyStopping counter: 6 out of 10
# Epoch 64/1000: [MSE: 0.0690], [KL: 0.3667], [Val_MSE: 0.0555], [Val_KL: 0.3672],
# EarlyStopping counter: 7 out of 10
# Epoch 65/1000: [MSE: 0.0649], [KL: 0.3672], [Val_MSE: 0.0554], [Val_KL: 0.3670],
# EarlyStopping counter: 8 out of 10
# Epoch 66/1000: [MSE: 0.0683], [KL: 0.3671], [Val_MSE: 0.0549], [Val_KL: 0.3662],
# EarlyStopping counter: 9 out of 10
# Epoch 67/1000: [MSE: 0.0672], [KL: 0.3670], [Val_MSE: 0.0539], [Val_KL: 0.3677],
# Validation loss decreased (0.054470 --> 0.053875).  Saving model ...
# Epoch 68/1000: [MSE: 0.0690], [KL: 0.3670], [Val_MSE: 0.0597], [Val_KL: 0.3655],
# EarlyStopping counter: 1 out of 10
# Epoch 69/1000: [MSE: 0.0672], [KL: 0.3671], [Val_MSE: 0.0558], [Val_KL: 0.3662],
# EarlyStopping counter: 2 out of 10
# Epoch 70/1000: [MSE: 0.0665], [KL: 0.3669], [Val_MSE: 0.0576], [Val_KL: 0.3658],
# EarlyStopping counter: 3 out of 10
# Epoch 71/1000: [MSE: 0.0680], [KL: 0.3669], [Val_MSE: 0.0556], [Val_KL: 0.3662],
# EarlyStopping counter: 4 out of 10
# Epoch 72/1000: [MSE: 0.0667], [KL: 0.3668], [Val_MSE: 0.0553], [Val_KL: 0.3663],
# EarlyStopping counter: 5 out of 10
# Epoch 73/1000: [MSE: 0.0644], [KL: 0.3668], [Val_MSE: 0.0552], [Val_KL: 0.3661],
# EarlyStopping counter: 6 out of 10
# Epoch 74/1000: [MSE: 0.0670], [KL: 0.3668], [Val_MSE: 0.0552], [Val_KL: 0.3663],
# EarlyStopping counter: 7 out of 10
# Epoch 75/1000: [MSE: 0.0668], [KL: 0.3669], [Val_MSE: 0.0546], [Val_KL: 0.3665],
# EarlyStopping counter: 8 out of 10
# Epoch 76/1000: [MSE: 0.0678], [KL: 0.3668], [Val_MSE: 0.0590], [Val_KL: 0.3656],
# EarlyStopping counter: 9 out of 10
# Epoch 77/1000: [MSE: 0.0672], [KL: 0.3669], [Val_MSE: 0.0569], [Val_KL: 0.3659],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, kl, val_mse, val_kl):
    fig, axs = plt.subplots(1,2, figsize=(10,4))
    axs[0].plot(mse, color='r', label='Training')
    axs[0].plot(val_mse, color='b', label='Validation')
    axs[0].set_title('MSE Loss')
    axs[1].plot(kl, color='r', label='Training')
    axs[1].plot(val_kl, color='b', label='Validation')
    axs[1].set_title('KL Loss')
    plt.legend()
    #plt.savefig('./imgMix/mse-kl-mvae.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, kl, val_mse, val_kl)

# %%
vae.eval()
Z = torch.tensor(Z, dtype=torch.float32).to(device)
Z_enc = vae(Z)

# %%
idx = 1001
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z[idx,:].cpu().detach().numpy()), label='Original')
axs.plot(np.transpose(Z_enc[idx,:].cpu().detach().numpy()), label='Reconstructed')
axs.set_title('Original vs. Reconstructed Signals')
plt.legend()
plt.show()

# %%
vae.eval()
Z_latent = vae.encoder(Z)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(Z_latent.cpu().detach().numpy()))
axs[0].set_title('Latent Noisy Sensor Signal')
axs[1].plot(np.transpose(Z_enc.cpu().detach().numpy()))
axs[1].set_title('Recunstructed Noisy Sensor Signal')
axs[2].plot(np.transpose(Z.cpu().detach().numpy()))
axs[2].set_title('Original Noisy Sensor Signal')
plt.show()

# %% [markdown]
# **$t=101$ latent distribution**

# %%
vae.eval()
sample_size = 30
signal = Z[100:102]
signal_latent, signal_rec = [], []
for _ in range(sample_size):
    signal_rec.append(vae(signal))
    signal_latent.append(vae.encoder(signal))
signal_latent = torch.stack(signal_latent, dim=0)
signal_rec = torch.stack(signal_rec, dim=0)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(signal_latent.cpu().detach().numpy()[:,0,:]))
axs[0].set_title(r'Latent Noisy Sensor Signal for $t=101$')
axs[1].plot(np.transpose(signal_rec.cpu().detach().numpy()[:,0,:]))
axs[1].set_title(r'Recunstructed Noisy Sensor Signal for $t=101$')
axs[2].plot(np.transpose(signal.cpu().detach().numpy()[0]))
axs[2].set_title(r'Original Noisy Sensor Signal for $t=101$')
plt.show()

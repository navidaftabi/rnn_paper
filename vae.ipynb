# %%
# which attack level to add noise
noise_type = 7
# how much noise to add: 0.00, 0.05, 0.10, 0.20, 0.50
noise_percent = 0.50

# %%
import re
import os
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae_trainer import VAETrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')

# %%
seed = 13
torch.manual_seed(seed)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class SensorDataset():
    def __init__(self, data: np.array):
        self.x = self.np2tensor(data)
        
    @staticmethod
    def np2tensor(x):
        return torch.tensor(x, dtype=torch.float32)
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx]

# %%
latent_dims = 118
batch_size = 16
epochs = 1000

# %%
data_filename = 'data.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)
train_size = int(T * 0.8)
lr = 1e-1
scheduler = True
es_patience = 10

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Original Sensor Signal')
plt.show()

# %%
# read attack noise
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  5.41it/s]

# %%
noise_size = int(T * noise_percent)
norm_operation_win = 50
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for _type in noise_to_add_from:
    noise_id = random.sample(range(int(2 * T / 3)), 1)
    noises.append(Z_noise[_type][noise_id])
random.shuffle(noises)
if len(noises) > 0:
    noises = np.concatenate(noises, axis=0)
    # add noises to original sensor data Z
    Z[noise_time,:] = noises

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Noisy Sensor Signal')
plt.show()

# %%
Z_train, Z_test = Z[:train_size], Z[train_size:]
training = SensorDataset(Z_train)
test = SensorDataset(Z_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = VAETrainer(latent_dim=latent_dims, lr=lr, 
                     lr_scheduler=scheduler, es_patience=es_patience,
                     checkpoint_name=f'vae_{int(noise_percent*100)}%.pt', 
                     seed=seed)

# %%
summary(trainer.vae, (1, 358))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [1, 358]                  --
# ├─VariationalEncoder: 1-1                [1, 118]                  --
# │    └─Linear: 2-1                       [1, 236]                  84,724
# │    └─BatchNorm1d: 2-2                  [1, 236]                  472
# │    └─Linear: 2-3                       [1, 118]                  27,966
# │    └─Linear: 2-4                       [1, 118]                  14,042
# │    └─Linear: 2-5                       [1, 118]                  14,042
# ├─Decoder: 1-2                           [1, 358]                  --
# │    └─Linear: 2-6                       [1, 236]                  28,084
# │    └─BatchNorm1d: 2-7                  [1, 236]                  472
# │    └─Linear: 2-8                       [1, 358]                  84,846
# ==========================================================================================
# Total params: 254,648
# Trainable params: 254,648
# Non-trainable params: 0
# Total mult-adds (M): 0.25
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ==========================================================================================

# %%
vae, mse, kl, val_mse, val_kl = trainer.train(train_dl, test_dl, epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 1.6829], [KL: 0.7962], [Val_MSE: 0.1771], [Val_KL: 0.3654],
# Validation loss decreased (inf --> 0.177093).  Saving model ...
# Epoch 2/1000: [MSE: 0.1324], [KL: 0.3736], [Val_MSE: 0.1180], [Val_KL: 0.3773],
# Validation loss decreased (0.177093 --> 0.118036).  Saving model ...
# Epoch 3/1000: [MSE: 0.1106], [KL: 0.3707], [Val_MSE: 0.1069], [Val_KL: 0.3960],
# Validation loss decreased (0.118036 --> 0.106893).  Saving model ...
# Epoch 4/1000: [MSE: 0.0974], [KL: 0.3678], [Val_MSE: 0.1017], [Val_KL: 0.3742],
# Validation loss decreased (0.106893 --> 0.101745).  Saving model ...
# Epoch 5/1000: [MSE: 0.0967], [KL: 0.3683], [Val_MSE: 0.0868], [Val_KL: 0.3734],
# Validation loss decreased (0.101745 --> 0.086843).  Saving model ...
# Epoch 6/1000: [MSE: 0.0911], [KL: 0.3675], [Val_MSE: 0.1140], [Val_KL: 0.3788],
# EarlyStopping counter: 1 out of 10
# Epoch 7/1000: [MSE: 0.0912], [KL: 0.3681], [Val_MSE: 0.0814], [Val_KL: 0.3682],
# Validation loss decreased (0.086843 --> 0.081411).  Saving model ...
# Epoch 8/1000: [MSE: 0.0945], [KL: 0.3675], [Val_MSE: 0.1461], [Val_KL: 0.3706],
# EarlyStopping counter: 1 out of 10
# Epoch 9/1000: [MSE: 0.0931], [KL: 0.3680], [Val_MSE: 0.0805], [Val_KL: 0.3695],
# Validation loss decreased (0.081411 --> 0.080504).  Saving model ...
# Epoch 10/1000: [MSE: 0.0932], [KL: 0.3680], [Val_MSE: 0.0943], [Val_KL: 0.3697],
# EarlyStopping counter: 1 out of 10
# Epoch 11/1000: [MSE: 0.0951], [KL: 0.3679], [Val_MSE: 0.0849], [Val_KL: 0.3675],
# EarlyStopping counter: 2 out of 10
# Epoch 12/1000: [MSE: 0.0880], [KL: 0.3682], [Val_MSE: 0.0946], [Val_KL: 0.3643],
# EarlyStopping counter: 3 out of 10
# Epoch 13/1000: [MSE: 0.0954], [KL: 0.3682], [Val_MSE: 0.1141], [Val_KL: 0.3706],
# EarlyStopping counter: 4 out of 10
# Epoch 14/1000: [MSE: 0.0969], [KL: 0.3681], [Val_MSE: 0.0961], [Val_KL: 0.3879],
# EarlyStopping counter: 5 out of 10
# Epoch 15/1000: [MSE: 0.0885], [KL: 0.3680], [Val_MSE: 0.0749], [Val_KL: 0.3722],
# Validation loss decreased (0.080504 --> 0.074887).  Saving model ...
# Epoch 16/1000: [MSE: 0.0903], [KL: 0.3681], [Val_MSE: 0.0939], [Val_KL: 0.3640],
# EarlyStopping counter: 1 out of 10
# Epoch 17/1000: [MSE: 0.0928], [KL: 0.3680], [Val_MSE: 0.0887], [Val_KL: 0.3679],
# EarlyStopping counter: 2 out of 10
# Epoch 18/1000: [MSE: 0.0921], [KL: 0.3676], [Val_MSE: 0.0807], [Val_KL: 0.3669],
# EarlyStopping counter: 3 out of 10
# Epoch 19/1000: [MSE: 0.0900], [KL: 0.3670], [Val_MSE: 0.0790], [Val_KL: 0.3699],
# EarlyStopping counter: 4 out of 10
# Epoch 20/1000: [MSE: 0.0902], [KL: 0.3671], [Val_MSE: 0.0974], [Val_KL: 0.3677],
# EarlyStopping counter: 5 out of 10
# Epoch 21/1000: [MSE: 0.0924], [KL: 0.3674], [Val_MSE: 0.1037], [Val_KL: 0.3674],
# EarlyStopping counter: 6 out of 10
# Epoch 22/1000: [MSE: 0.0930], [KL: 0.3673], [Val_MSE: 0.0888], [Val_KL: 0.3698],
# EarlyStopping counter: 7 out of 10
# Epoch 23/1000: [MSE: 0.0782], [KL: 0.3657], [Val_MSE: 0.0700], [Val_KL: 0.3659],
# Validation loss decreased (0.074887 --> 0.070034).  Saving model ...
# Epoch 24/1000: [MSE: 0.0766], [KL: 0.3661], [Val_MSE: 0.0673], [Val_KL: 0.3675],
# Validation loss decreased (0.070034 --> 0.067318).  Saving model ...
# Epoch 25/1000: [MSE: 0.0766], [KL: 0.3659], [Val_MSE: 0.0732], [Val_KL: 0.3675],
# EarlyStopping counter: 1 out of 10
# Epoch 26/1000: [MSE: 0.0772], [KL: 0.3663], [Val_MSE: 0.0687], [Val_KL: 0.3663],
# EarlyStopping counter: 2 out of 10
# Epoch 27/1000: [MSE: 0.0778], [KL: 0.3661], [Val_MSE: 0.0686], [Val_KL: 0.3681],
# EarlyStopping counter: 3 out of 10
# Epoch 28/1000: [MSE: 0.0802], [KL: 0.3662], [Val_MSE: 0.0694], [Val_KL: 0.3650],
# EarlyStopping counter: 4 out of 10
# Epoch 29/1000: [MSE: 0.0761], [KL: 0.3667], [Val_MSE: 0.0681], [Val_KL: 0.3673],
# EarlyStopping counter: 5 out of 10
# Epoch 30/1000: [MSE: 0.0740], [KL: 0.3669], [Val_MSE: 0.0680], [Val_KL: 0.3658],
# EarlyStopping counter: 6 out of 10
# Epoch 31/1000: [MSE: 0.0751], [KL: 0.3670], [Val_MSE: 0.0677], [Val_KL: 0.3663],
# EarlyStopping counter: 7 out of 10
# Epoch 32/1000: [MSE: 0.0719], [KL: 0.3666], [Val_MSE: 0.0619], [Val_KL: 0.3691],
# Validation loss decreased (0.067318 --> 0.061905).  Saving model ...
# Epoch 33/1000: [MSE: 0.0705], [KL: 0.3669], [Val_MSE: 0.0617], [Val_KL: 0.3681],
# Validation loss decreased (0.061905 --> 0.061703).  Saving model ...
# Epoch 34/1000: [MSE: 0.0673], [KL: 0.3669], [Val_MSE: 0.0619], [Val_KL: 0.3673],
# EarlyStopping counter: 1 out of 10
# Epoch 35/1000: [MSE: 0.0693], [KL: 0.3672], [Val_MSE: 0.0637], [Val_KL: 0.3672],
# EarlyStopping counter: 2 out of 10
# Epoch 36/1000: [MSE: 0.0708], [KL: 0.3674], [Val_MSE: 0.0646], [Val_KL: 0.3666],
# EarlyStopping counter: 3 out of 10
# Epoch 37/1000: [MSE: 0.0691], [KL: 0.3675], [Val_MSE: 0.0628], [Val_KL: 0.3676],
# EarlyStopping counter: 4 out of 10
# Epoch 38/1000: [MSE: 0.0684], [KL: 0.3670], [Val_MSE: 0.0596], [Val_KL: 0.3686],
# Validation loss decreased (0.061703 --> 0.059625).  Saving model ...
# Epoch 39/1000: [MSE: 0.0695], [KL: 0.3671], [Val_MSE: 0.0606], [Val_KL: 0.3674],
# EarlyStopping counter: 1 out of 10
# Epoch 40/1000: [MSE: 0.0670], [KL: 0.3673], [Val_MSE: 0.0614], [Val_KL: 0.3672],
# EarlyStopping counter: 2 out of 10
# Epoch 41/1000: [MSE: 0.0672], [KL: 0.3674], [Val_MSE: 0.0594], [Val_KL: 0.3686],
# Validation loss decreased (0.059625 --> 0.059414).  Saving model ...
# Epoch 42/1000: [MSE: 0.0673], [KL: 0.3673], [Val_MSE: 0.0608], [Val_KL: 0.3675],
# EarlyStopping counter: 1 out of 10
# Epoch 43/1000: [MSE: 0.0672], [KL: 0.3670], [Val_MSE: 0.0594], [Val_KL: 0.3690],
# EarlyStopping counter: 2 out of 10
# Epoch 44/1000: [MSE: 0.0681], [KL: 0.3674], [Val_MSE: 0.0606], [Val_KL: 0.3687],
# EarlyStopping counter: 3 out of 10
# Epoch 45/1000: [MSE: 0.0682], [KL: 0.3673], [Val_MSE: 0.0603], [Val_KL: 0.3685],
# EarlyStopping counter: 4 out of 10
# Epoch 46/1000: [MSE: 0.0661], [KL: 0.3672], [Val_MSE: 0.0601], [Val_KL: 0.3680],
# EarlyStopping counter: 5 out of 10
# Epoch 47/1000: [MSE: 0.0676], [KL: 0.3671], [Val_MSE: 0.0610], [Val_KL: 0.3683],
# EarlyStopping counter: 6 out of 10
# Epoch 48/1000: [MSE: 0.0684], [KL: 0.3674], [Val_MSE: 0.0586], [Val_KL: 0.3684],
# Validation loss decreased (0.059414 --> 0.058610).  Saving model ...
# Epoch 49/1000: [MSE: 0.0682], [KL: 0.3673], [Val_MSE: 0.0606], [Val_KL: 0.3683],
# EarlyStopping counter: 1 out of 10
# Epoch 50/1000: [MSE: 0.0680], [KL: 0.3676], [Val_MSE: 0.0603], [Val_KL: 0.3687],
# EarlyStopping counter: 2 out of 10
# Epoch 51/1000: [MSE: 0.0686], [KL: 0.3673], [Val_MSE: 0.0634], [Val_KL: 0.3678],
# EarlyStopping counter: 3 out of 10
# Epoch 52/1000: [MSE: 0.0685], [KL: 0.3674], [Val_MSE: 0.0590], [Val_KL: 0.3696],
# EarlyStopping counter: 4 out of 10
# Epoch 53/1000: [MSE: 0.0688], [KL: 0.3671], [Val_MSE: 0.0638], [Val_KL: 0.3665],
# EarlyStopping counter: 5 out of 10
# Epoch 54/1000: [MSE: 0.0680], [KL: 0.3674], [Val_MSE: 0.0643], [Val_KL: 0.3668],
# EarlyStopping counter: 6 out of 10
# Epoch 55/1000: [MSE: 0.0694], [KL: 0.3675], [Val_MSE: 0.0599], [Val_KL: 0.3687],
# EarlyStopping counter: 7 out of 10
# Epoch 56/1000: [MSE: 0.0660], [KL: 0.3678], [Val_MSE: 0.0579], [Val_KL: 0.3691],
# Validation loss decreased (0.058610 --> 0.057950).  Saving model ...
# Epoch 57/1000: [MSE: 0.0657], [KL: 0.3674], [Val_MSE: 0.0600], [Val_KL: 0.3681],
# EarlyStopping counter: 1 out of 10
# Epoch 58/1000: [MSE: 0.0659], [KL: 0.3676], [Val_MSE: 0.0599], [Val_KL: 0.3682],
# EarlyStopping counter: 2 out of 10
# Epoch 59/1000: [MSE: 0.0664], [KL: 0.3678], [Val_MSE: 0.0589], [Val_KL: 0.3709],
# EarlyStopping counter: 3 out of 10
# Epoch 60/1000: [MSE: 0.0660], [KL: 0.3676], [Val_MSE: 0.0588], [Val_KL: 0.3695],
# EarlyStopping counter: 4 out of 10
# Epoch 61/1000: [MSE: 0.0661], [KL: 0.3677], [Val_MSE: 0.0583], [Val_KL: 0.3692],
# EarlyStopping counter: 5 out of 10
# Epoch 62/1000: [MSE: 0.0658], [KL: 0.3673], [Val_MSE: 0.0602], [Val_KL: 0.3690],
# EarlyStopping counter: 6 out of 10
# Epoch 63/1000: [MSE: 0.0669], [KL: 0.3674], [Val_MSE: 0.0600], [Val_KL: 0.3689],
# EarlyStopping counter: 7 out of 10
# Epoch 64/1000: [MSE: 0.0664], [KL: 0.3674], [Val_MSE: 0.0603], [Val_KL: 0.3681],
# EarlyStopping counter: 8 out of 10
# Epoch 65/1000: [MSE: 0.0665], [KL: 0.3675], [Val_MSE: 0.0583], [Val_KL: 0.3691],
# EarlyStopping counter: 9 out of 10
# Epoch 66/1000: [MSE: 0.0673], [KL: 0.3675], [Val_MSE: 0.0587], [Val_KL: 0.3690],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, kl, val_mse, val_kl):
    fig, axs = plt.subplots(1,2, figsize=(10,4))
    axs[0].plot(mse, color='r', label='Training')
    axs[0].plot(val_mse, color='b', label='Validation')
    axs[0].set_title('MSE Loss')
    axs[1].plot(kl, color='r', label='Training')
    axs[1].plot(val_kl, color='b', label='Validation')
    axs[1].set_title('KL Loss')
    plt.legend()
    #plt.savefig('./imgMix/mse-kl-mvae.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, kl, val_mse, val_kl)

# %%
vae.eval()
Z = torch.tensor(Z, dtype=torch.float32).to(device)
Z_enc = vae(Z)

# %%
idx = 1001
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z[idx,:].cpu().detach().numpy()), label='Original')
axs.plot(np.transpose(Z_enc[idx,:].cpu().detach().numpy()), label='Reconstructed')
axs.set_title('Original vs. Reconstructed Signals')
plt.legend()
plt.show()

# %%
vae.eval()
Z_latent = vae.encoder(Z)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(Z_latent.cpu().detach().numpy()))
axs[0].set_title('Latent Noisy Sensor Signal')
axs[1].plot(np.transpose(Z_enc.cpu().detach().numpy()))
axs[1].set_title('Recunstructed Noisy Sensor Signal')
axs[2].plot(np.transpose(Z.cpu().detach().numpy()))
axs[2].set_title('Original Noisy Sensor Signal')
plt.show()

# %% [markdown]
# **$t=101$ latent distribution**

# %%
vae.eval()
sample_size = 30
signal = Z[100:102]
signal_latent, signal_rec = [], []
for _ in range(sample_size):
    signal_rec.append(vae(signal))
    signal_latent.append(vae.encoder(signal))
signal_latent = torch.stack(signal_latent, dim=0)
signal_rec = torch.stack(signal_rec, dim=0)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(signal_latent.cpu().detach().numpy()[:,0,:]))
axs[0].set_title(r'Latent Noisy Sensor Signal for $t=101$')
axs[1].plot(np.transpose(signal_rec.cpu().detach().numpy()[:,0,:]))
axs[1].set_title(r'Recunstructed Noisy Sensor Signal for $t=101$')
axs[2].plot(np.transpose(signal.cpu().detach().numpy()[0]))
axs[2].set_title(r'Original Noisy Sensor Signal for $t=101$')
plt.show()

# %%
# which attack level to add noise
noise_type = 7
# how much noise to add: 0.00, 0.05, 0.10, 0.20, 0.50
noise_percent = 0.50

# %%
import re
import os
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae_trainer import VAETrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')

# %%
seed = 37
torch.manual_seed(seed)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class SensorDataset():
    def __init__(self, data: np.array):
        self.x = self.np2tensor(data)
        
    @staticmethod
    def np2tensor(x):
        return torch.tensor(x, dtype=torch.float32)
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx]

# %%
latent_dims = 118
batch_size = 16
epochs = 1000

# %%
data_filename = 'data.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)
train_size = int(T * 0.8)
lr = 1e-1
scheduler = True
es_patience = 10

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Original Sensor Signal')
plt.show()

# %%
# read attack noise
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  6.11it/s]

# %%
noise_size = int(T * noise_percent)
norm_operation_win = 50
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for _type in noise_to_add_from:
    noise_id = random.sample(range(T), 1)
    noises.append(Z_noise[_type][noise_id])
random.shuffle(noises)
if len(noises) > 0:
    noises = np.concatenate(noises, axis=0)
    # add noises to original sensor data Z
    Z[noise_time,:] = noises

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Noisy Sensor Signal')
plt.show()

# %%
Z_train, Z_test = Z[:train_size], Z[train_size:]
training = SensorDataset(Z_train)
test = SensorDataset(Z_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = VAETrainer(latent_dim=latent_dims, lr=lr, 
                     lr_scheduler=scheduler, es_patience=es_patience,
                     checkpoint_name=f'vae_{int(noise_percent*100)}%.pt', 
                     seed=seed)
# Out:
# Device:  cuda

# %%
summary(trainer.vae, (1, 358))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [1, 358]                  --
# ├─VariationalEncoder: 1-1                [1, 118]                  --
# │    └─Linear: 2-1                       [1, 236]                  84,724
# │    └─BatchNorm1d: 2-2                  [1, 236]                  472
# │    └─Linear: 2-3                       [1, 118]                  27,966
# │    └─Linear: 2-4                       [1, 118]                  14,042
# │    └─Linear: 2-5                       [1, 118]                  14,042
# ├─Decoder: 1-2                           [1, 358]                  --
# │    └─Linear: 2-6                       [1, 236]                  28,084
# │    └─BatchNorm1d: 2-7                  [1, 236]                  472
# │    └─Linear: 2-8                       [1, 358]                  84,846
# ==========================================================================================
# Total params: 254,648
# Trainable params: 254,648
# Non-trainable params: 0
# Total mult-adds (M): 0.25
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ==========================================================================================

# %%
vae, mse, kl, val_mse, val_kl = trainer.train(train_dl, test_dl, epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 1.6633], [KL: 0.9468], [Val_MSE: 0.1399], [Val_KL: 0.3582],
# Validation loss decreased (inf --> 0.139896).  Saving model ...
# Epoch 2/1000: [MSE: 0.1220], [KL: 0.3661], [Val_MSE: 0.1166], [Val_KL: 0.3744],
# Validation loss decreased (0.139896 --> 0.116617).  Saving model ...
# Epoch 3/1000: [MSE: 0.1074], [KL: 0.3641], [Val_MSE: 0.0999], [Val_KL: 0.3603],
# Validation loss decreased (0.116617 --> 0.099850).  Saving model ...
# Epoch 4/1000: [MSE: 0.1064], [KL: 0.3641], [Val_MSE: 0.1107], [Val_KL: 0.3623],
# EarlyStopping counter: 1 out of 10
# Epoch 5/1000: [MSE: 0.1026], [KL: 0.3637], [Val_MSE: 0.0977], [Val_KL: 0.3584],
# Validation loss decreased (0.099850 --> 0.097670).  Saving model ...
# Epoch 6/1000: [MSE: 0.1081], [KL: 0.3631], [Val_MSE: 0.0975], [Val_KL: 0.3597],
# Validation loss decreased (0.097670 --> 0.097530).  Saving model ...
# Epoch 7/1000: [MSE: 0.1069], [KL: 0.3633], [Val_MSE: 0.1129], [Val_KL: 0.3602],
# EarlyStopping counter: 1 out of 10
# Epoch 8/1000: [MSE: 0.1067], [KL: 0.3620], [Val_MSE: 0.1832], [Val_KL: 0.3608],
# EarlyStopping counter: 2 out of 10
# Epoch 9/1000: [MSE: 0.1115], [KL: 0.3667], [Val_MSE: 0.1074], [Val_KL: 0.3610],
# EarlyStopping counter: 3 out of 10
# Epoch 10/1000: [MSE: 0.1030], [KL: 0.3614], [Val_MSE: 0.1050], [Val_KL: 0.3598],
# EarlyStopping counter: 4 out of 10
# Epoch 11/1000: [MSE: 0.1054], [KL: 0.3619], [Val_MSE: 0.1057], [Val_KL: 0.3592],
# EarlyStopping counter: 5 out of 10
# Epoch 12/1000: [MSE: 0.1064], [KL: 0.3617], [Val_MSE: 0.1140], [Val_KL: 0.3586],
# EarlyStopping counter: 6 out of 10
# Epoch 13/1000: [MSE: 0.1072], [KL: 0.3616], [Val_MSE: 0.1036], [Val_KL: 0.3632],
# EarlyStopping counter: 7 out of 10
# Epoch 14/1000: [MSE: 0.0955], [KL: 0.3603], [Val_MSE: 0.0964], [Val_KL: 0.3610],
# Validation loss decreased (0.097530 --> 0.096405).  Saving model ...
# Epoch 15/1000: [MSE: 0.0970], [KL: 0.3602], [Val_MSE: 0.0825], [Val_KL: 0.3605],
# Validation loss decreased (0.096405 --> 0.082475).  Saving model ...
# Epoch 16/1000: [MSE: 0.0941], [KL: 0.3603], [Val_MSE: 0.0801], [Val_KL: 0.3608],
# Validation loss decreased (0.082475 --> 0.080067).  Saving model ...
# Epoch 17/1000: [MSE: 0.0960], [KL: 0.3602], [Val_MSE: 0.0847], [Val_KL: 0.3636],
# EarlyStopping counter: 1 out of 10
# Epoch 18/1000: [MSE: 0.0934], [KL: 0.3605], [Val_MSE: 0.0775], [Val_KL: 0.3609],
# Validation loss decreased (0.080067 --> 0.077473).  Saving model ...
# Epoch 19/1000: [MSE: 0.0974], [KL: 0.3604], [Val_MSE: 0.0792], [Val_KL: 0.3607],
# EarlyStopping counter: 1 out of 10
# Epoch 20/1000: [MSE: 0.0952], [KL: 0.3601], [Val_MSE: 0.0833], [Val_KL: 0.3605],
# EarlyStopping counter: 2 out of 10
# Epoch 21/1000: [MSE: 0.0955], [KL: 0.3604], [Val_MSE: 0.0784], [Val_KL: 0.3609],
# EarlyStopping counter: 3 out of 10
# Epoch 22/1000: [MSE: 0.0938], [KL: 0.3604], [Val_MSE: 0.0825], [Val_KL: 0.3610],
# EarlyStopping counter: 4 out of 10
# Epoch 23/1000: [MSE: 0.0952], [KL: 0.3604], [Val_MSE: 0.0789], [Val_KL: 0.3606],
# EarlyStopping counter: 5 out of 10
# Epoch 24/1000: [MSE: 0.0958], [KL: 0.3603], [Val_MSE: 0.0908], [Val_KL: 0.3599],
# EarlyStopping counter: 6 out of 10
# Epoch 25/1000: [MSE: 0.0939], [KL: 0.3601], [Val_MSE: 0.0820], [Val_KL: 0.3593],
# EarlyStopping counter: 7 out of 10
# Epoch 26/1000: [MSE: 0.0940], [KL: 0.3598], [Val_MSE: 0.0780], [Val_KL: 0.3609],
# EarlyStopping counter: 8 out of 10
# Epoch 27/1000: [MSE: 0.0931], [KL: 0.3601], [Val_MSE: 0.0795], [Val_KL: 0.3607],
# EarlyStopping counter: 9 out of 10
# Epoch 28/1000: [MSE: 0.0909], [KL: 0.3600], [Val_MSE: 0.0761], [Val_KL: 0.3605],
# Validation loss decreased (0.077473 --> 0.076131).  Saving model ...
# Epoch 29/1000: [MSE: 0.0914], [KL: 0.3599], [Val_MSE: 0.0769], [Val_KL: 0.3610],
# EarlyStopping counter: 1 out of 10
# Epoch 30/1000: [MSE: 0.0926], [KL: 0.3601], [Val_MSE: 0.0771], [Val_KL: 0.3605],
# EarlyStopping counter: 2 out of 10
# Epoch 31/1000: [MSE: 0.0925], [KL: 0.3600], [Val_MSE: 0.0772], [Val_KL: 0.3609],
# EarlyStopping counter: 3 out of 10
# Epoch 32/1000: [MSE: 0.0897], [KL: 0.3600], [Val_MSE: 0.0782], [Val_KL: 0.3602],
# EarlyStopping counter: 4 out of 10
# Epoch 33/1000: [MSE: 0.0906], [KL: 0.3603], [Val_MSE: 0.0774], [Val_KL: 0.3604],
# EarlyStopping counter: 5 out of 10
# Epoch 34/1000: [MSE: 0.0929], [KL: 0.3600], [Val_MSE: 0.0770], [Val_KL: 0.3607],
# EarlyStopping counter: 6 out of 10
# Epoch 35/1000: [MSE: 0.0921], [KL: 0.3601], [Val_MSE: 0.0790], [Val_KL: 0.3601],
# EarlyStopping counter: 7 out of 10
# Epoch 36/1000: [MSE: 0.0912], [KL: 0.3598], [Val_MSE: 0.0781], [Val_KL: 0.3601],
# EarlyStopping counter: 8 out of 10
# Epoch 37/1000: [MSE: 0.0913], [KL: 0.3598], [Val_MSE: 0.0774], [Val_KL: 0.3601],
# EarlyStopping counter: 9 out of 10
# Epoch 38/1000: [MSE: 0.0904], [KL: 0.3597], [Val_MSE: 0.0773], [Val_KL: 0.3603],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, kl, val_mse, val_kl):
    fig, axs = plt.subplots(1,2, figsize=(10,4))
    axs[0].plot(mse, color='r', label='Training')
    axs[0].plot(val_mse, color='b', label='Validation')
    axs[0].set_title('MSE Loss')
    axs[1].plot(kl, color='r', label='Training')
    axs[1].plot(val_kl, color='b', label='Validation')
    axs[1].set_title('KL Loss')
    plt.legend()
    #plt.savefig('./imgMix/mse-kl-mvae.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, kl, val_mse, val_kl)

# %%
vae.eval()
Z = torch.tensor(Z, dtype=torch.float32).to(device)
Z_enc = vae(Z)

# %%
idx = 1001
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z[idx,:].cpu().detach().numpy()), label='Original')
axs.plot(np.transpose(Z_enc[idx,:].cpu().detach().numpy()), label='Reconstructed')
axs.set_title('Original vs. Reconstructed Signals')
plt.legend()
plt.show()

# %%
vae.eval()
Z_latent = vae.encoder(Z)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(Z_latent.cpu().detach().numpy()))
axs[0].set_title('Latent Noisy Sensor Signal')
axs[1].plot(np.transpose(Z_enc.cpu().detach().numpy()))
axs[1].set_title('Recunstructed Noisy Sensor Signal')
axs[2].plot(np.transpose(Z.cpu().detach().numpy()))
axs[2].set_title('Original Noisy Sensor Signal')
plt.show()

# %% [markdown]
# **$t=101$ latent distribution**

# %%
vae.eval()
sample_size = 30
signal = Z[100:102]
signal_latent, signal_rec = [], []
for _ in range(sample_size):
    signal_rec.append(vae(signal))
    signal_latent.append(vae.encoder(signal))
signal_latent = torch.stack(signal_latent, dim=0)
signal_rec = torch.stack(signal_rec, dim=0)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(signal_latent.cpu().detach().numpy()[:,0,:]))
axs[0].set_title(r'Latent Noisy Sensor Signal for $t=101$')
axs[1].plot(np.transpose(signal_rec.cpu().detach().numpy()[:,0,:]))
axs[1].set_title(r'Recunstructed Noisy Sensor Signal for $t=101$')
axs[2].plot(np.transpose(signal.cpu().detach().numpy()[0]))
axs[2].set_title(r'Original Noisy Sensor Signal for $t=101$')
plt.show()

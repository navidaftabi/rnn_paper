# %%
# which attack level to add noise
noise_type = 7
# how much noise to add: 0.00, 0.05, 0.10, 0.20, 0.50
noise_percent = 0.00

# %%
import re
import os
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae_trainer import VAETrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')

# %%
seed = 47
torch.manual_seed(seed)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class SensorDataset():
    def __init__(self, data: np.array):
        self.x = self.np2tensor(data)
        
    @staticmethod
    def np2tensor(x):
        return torch.tensor(x, dtype=torch.float32)
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx]

# %%
latent_dims = 118
batch_size = 16
epochs = 1000

# %%
data_filename = 'data.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)
train_size = int(T * 0.8)
lr = 1e-1
scheduler = True
es_patience = 10

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Original Sensor Signal')
plt.show()

# %%
# read attack noise
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  6.91it/s]

# %%
noise_size = int(T * noise_percent)
norm_operation_win = 50
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for _type in noise_to_add_from:
    noise_id = random.sample(range(T), 1)
    noises.append(Z_noise[_type][noise_id])
random.shuffle(noises)
if len(noises) > 0:
    noises = np.concatenate(noises, axis=0)
    # add noises to original sensor data Z
    Z[noise_time,:] = noises

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Noisy Sensor Signal')
plt.show()

# %%
Z_train, Z_test = Z[:train_size], Z[train_size:]
training = SensorDataset(Z_train)
test = SensorDataset(Z_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = VAETrainer(latent_dim=latent_dims, lr=lr, 
                     lr_scheduler=scheduler, es_patience=es_patience,
                     checkpoint_name=f'vae_{int(noise_percent*100)}%.pt', 
                     seed=seed)

# %%
summary(trainer.vae, (1, 358))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [1, 358]                  --
# ├─VariationalEncoder: 1-1                [1, 118]                  --
# │    └─Linear: 2-1                       [1, 236]                  84,724
# │    └─BatchNorm1d: 2-2                  [1, 236]                  472
# │    └─Linear: 2-3                       [1, 118]                  27,966
# │    └─Linear: 2-4                       [1, 118]                  14,042
# │    └─Linear: 2-5                       [1, 118]                  14,042
# ├─Decoder: 1-2                           [1, 358]                  --
# │    └─Linear: 2-6                       [1, 236]                  28,084
# │    └─BatchNorm1d: 2-7                  [1, 236]                  472
# │    └─Linear: 2-8                       [1, 358]                  84,846
# ==========================================================================================
# Total params: 254,648
# Trainable params: 254,648
# Non-trainable params: 0
# Total mult-adds (M): 0.25
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ==========================================================================================

# %%
vae, mse, kl, val_mse, val_kl = trainer.train(train_dl, test_dl, epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 1.3715], [KL: 1.3848], [Val_MSE: 0.1042], [Val_KL: 0.4062],
# Validation loss decreased (inf --> 0.104229).  Saving model ...
# Epoch 2/1000: [MSE: 0.1168], [KL: 0.3646], [Val_MSE: 0.1207], [Val_KL: 0.3782],
# EarlyStopping counter: 1 out of 10
# Epoch 3/1000: [MSE: 0.1163], [KL: 0.3639], [Val_MSE: 0.1082], [Val_KL: 0.3712],
# EarlyStopping counter: 2 out of 10
# Epoch 4/1000: [MSE: 0.1102], [KL: 0.3626], [Val_MSE: 0.1337], [Val_KL: 0.3707],
# EarlyStopping counter: 3 out of 10
# Epoch 5/1000: [MSE: 0.1079], [KL: 0.3611], [Val_MSE: 0.0984], [Val_KL: 0.3632],
# Validation loss decreased (0.104229 --> 0.098368).  Saving model ...
# Epoch 6/1000: [MSE: 0.1037], [KL: 0.3605], [Val_MSE: 0.0899], [Val_KL: 0.3627],
# Validation loss decreased (0.098368 --> 0.089940).  Saving model ...
# Epoch 7/1000: [MSE: 0.1051], [KL: 0.3603], [Val_MSE: 0.1040], [Val_KL: 0.3635],
# EarlyStopping counter: 1 out of 10
# Epoch 8/1000: [MSE: 0.1035], [KL: 0.3596], [Val_MSE: 0.0935], [Val_KL: 0.3608],
# EarlyStopping counter: 2 out of 10
# Epoch 9/1000: [MSE: 0.0991], [KL: 0.3597], [Val_MSE: 0.1051], [Val_KL: 0.3604],
# EarlyStopping counter: 3 out of 10
# Epoch 10/1000: [MSE: 0.1027], [KL: 0.3599], [Val_MSE: 0.1199], [Val_KL: 0.3609],
# EarlyStopping counter: 4 out of 10
# Epoch 11/1000: [MSE: 0.1037], [KL: 0.3595], [Val_MSE: 0.1026], [Val_KL: 0.3628],
# EarlyStopping counter: 5 out of 10
# Epoch 12/1000: [MSE: 0.1039], [KL: 0.3598], [Val_MSE: 0.1046], [Val_KL: 0.3607],
# EarlyStopping counter: 6 out of 10
# Epoch 13/1000: [MSE: 0.1044], [KL: 0.3600], [Val_MSE: 0.0888], [Val_KL: 0.3630],
# Validation loss decreased (0.089940 --> 0.088775).  Saving model ...
# Epoch 14/1000: [MSE: 0.1024], [KL: 0.3596], [Val_MSE: 0.1186], [Val_KL: 0.3595],
# EarlyStopping counter: 1 out of 10
# Epoch 15/1000: [MSE: 0.0991], [KL: 0.3596], [Val_MSE: 0.1170], [Val_KL: 0.3603],
# EarlyStopping counter: 2 out of 10
# Epoch 16/1000: [MSE: 0.0999], [KL: 0.3598], [Val_MSE: 0.1035], [Val_KL: 0.3590],
# EarlyStopping counter: 3 out of 10
# Epoch 17/1000: [MSE: 0.0976], [KL: 0.3599], [Val_MSE: 0.0963], [Val_KL: 0.3620],
# EarlyStopping counter: 4 out of 10
# Epoch 18/1000: [MSE: 0.1055], [KL: 0.3598], [Val_MSE: 0.0948], [Val_KL: 0.3616],
# EarlyStopping counter: 5 out of 10
# Epoch 19/1000: [MSE: 0.1060], [KL: 0.3596], [Val_MSE: 0.0908], [Val_KL: 0.3664],
# EarlyStopping counter: 6 out of 10
# Epoch 20/1000: [MSE: 0.1042], [KL: 0.3600], [Val_MSE: 0.1048], [Val_KL: 0.3652],
# EarlyStopping counter: 7 out of 10
# Epoch 21/1000: [MSE: 0.0933], [KL: 0.3594], [Val_MSE: 0.0877], [Val_KL: 0.3599],
# Validation loss decreased (0.088775 --> 0.087667).  Saving model ...
# Epoch 22/1000: [MSE: 0.0896], [KL: 0.3594], [Val_MSE: 0.0872], [Val_KL: 0.3607],
# Validation loss decreased (0.087667 --> 0.087243).  Saving model ...
# Epoch 23/1000: [MSE: 0.0904], [KL: 0.3595], [Val_MSE: 0.0838], [Val_KL: 0.3623],
# Validation loss decreased (0.087243 --> 0.083774).  Saving model ...
# Epoch 24/1000: [MSE: 0.0908], [KL: 0.3592], [Val_MSE: 0.0856], [Val_KL: 0.3613],
# EarlyStopping counter: 1 out of 10
# Epoch 25/1000: [MSE: 0.0918], [KL: 0.3592], [Val_MSE: 0.0831], [Val_KL: 0.3613],
# Validation loss decreased (0.083774 --> 0.083145).  Saving model ...
# Epoch 26/1000: [MSE: 0.0927], [KL: 0.3592], [Val_MSE: 0.0830], [Val_KL: 0.3603],
# Validation loss decreased (0.083145 --> 0.082974).  Saving model ...
# Epoch 27/1000: [MSE: 0.0938], [KL: 0.3593], [Val_MSE: 0.0830], [Val_KL: 0.3619],
# EarlyStopping counter: 1 out of 10
# Epoch 28/1000: [MSE: 0.0911], [KL: 0.3592], [Val_MSE: 0.0834], [Val_KL: 0.3616],
# EarlyStopping counter: 2 out of 10
# Epoch 29/1000: [MSE: 0.0894], [KL: 0.3593], [Val_MSE: 0.0857], [Val_KL: 0.3612],
# EarlyStopping counter: 3 out of 10
# Epoch 30/1000: [MSE: 0.0942], [KL: 0.3592], [Val_MSE: 0.0807], [Val_KL: 0.3625],
# Validation loss decreased (0.082974 --> 0.080685).  Saving model ...
# Epoch 31/1000: [MSE: 0.0909], [KL: 0.3594], [Val_MSE: 0.0866], [Val_KL: 0.3609],
# EarlyStopping counter: 1 out of 10
# Epoch 32/1000: [MSE: 0.0919], [KL: 0.3591], [Val_MSE: 0.0824], [Val_KL: 0.3618],
# EarlyStopping counter: 2 out of 10
# Epoch 33/1000: [MSE: 0.0928], [KL: 0.3594], [Val_MSE: 0.0841], [Val_KL: 0.3606],
# EarlyStopping counter: 3 out of 10
# Epoch 34/1000: [MSE: 0.0928], [KL: 0.3588], [Val_MSE: 0.0842], [Val_KL: 0.3616],
# EarlyStopping counter: 4 out of 10
# Epoch 35/1000: [MSE: 0.0915], [KL: 0.3592], [Val_MSE: 0.0835], [Val_KL: 0.3618],
# EarlyStopping counter: 5 out of 10
# Epoch 36/1000: [MSE: 0.0922], [KL: 0.3593], [Val_MSE: 0.0846], [Val_KL: 0.3618],
# EarlyStopping counter: 6 out of 10
# Epoch 37/1000: [MSE: 0.0937], [KL: 0.3591], [Val_MSE: 0.0825], [Val_KL: 0.3624],
# EarlyStopping counter: 7 out of 10
# Epoch 38/1000: [MSE: 0.0927], [KL: 0.3593], [Val_MSE: 0.0819], [Val_KL: 0.3609],
# EarlyStopping counter: 8 out of 10
# Epoch 39/1000: [MSE: 0.0885], [KL: 0.3591], [Val_MSE: 0.0808], [Val_KL: 0.3611],
# EarlyStopping counter: 9 out of 10
# Epoch 40/1000: [MSE: 0.0880], [KL: 0.3588], [Val_MSE: 0.0838], [Val_KL: 0.3599],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, kl, val_mse, val_kl):
    fig, axs = plt.subplots(1,2, figsize=(10,4))
    axs[0].plot(mse, color='r', label='Training')
    axs[0].plot(val_mse, color='b', label='Validation')
    axs[0].set_title('MSE Loss')
    axs[1].plot(kl, color='r', label='Training')
    axs[1].plot(val_kl, color='b', label='Validation')
    axs[1].set_title('KL Loss')
    plt.legend()
    #plt.savefig('./imgMix/mse-kl-mvae.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, kl, val_mse, val_kl)

# %%
vae.eval()
Z = torch.tensor(Z, dtype=torch.float32).to(device)
Z_enc = vae(Z)

# %%
idx = 1001
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z[idx,:].cpu().detach().numpy()), label='Original')
axs.plot(np.transpose(Z_enc[idx,:].cpu().detach().numpy()), label='Reconstructed')
axs.set_title('Original vs. Reconstructed Signals')
plt.legend()
plt.show()

# %%
vae.eval()
Z_latent = vae.encoder(Z)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(Z_latent.cpu().detach().numpy()))
axs[0].set_title('Latent Noisy Sensor Signal')
axs[1].plot(np.transpose(Z_enc.cpu().detach().numpy()))
axs[1].set_title('Recunstructed Noisy Sensor Signal')
axs[2].plot(np.transpose(Z.cpu().detach().numpy()))
axs[2].set_title('Original Noisy Sensor Signal')
plt.show()

# %% [markdown]
# **$t=101$ latent distribution**

# %%
vae.eval()
sample_size = 30
signal = Z[100:102]
signal_latent, signal_rec = [], []
for _ in range(sample_size):
    signal_rec.append(vae(signal))
    signal_latent.append(vae.encoder(signal))
signal_latent = torch.stack(signal_latent, dim=0)
signal_rec = torch.stack(signal_rec, dim=0)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(signal_latent.cpu().detach().numpy()[:,0,:]))
axs[0].set_title(r'Latent Noisy Sensor Signal for $t=101$')
axs[1].plot(np.transpose(signal_rec.cpu().detach().numpy()[:,0,:]))
axs[1].set_title(r'Recunstructed Noisy Sensor Signal for $t=101$')
axs[2].plot(np.transpose(signal.cpu().detach().numpy()[0]))
axs[2].set_title(r'Original Noisy Sensor Signal for $t=101$')
plt.show()

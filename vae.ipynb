# %%
# which attack level to add noise
noise_type = 7
# how much noise to add: 0.00, 0.05, 0.10, 0.20, 0.50
noise_percent = 0.00

# %%
import re
import os
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae_trainer import VAETrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')

# %%
seed = 37
torch.manual_seed(seed)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class SensorDataset():
    def __init__(self, data: np.array):
        self.x = self.np2tensor(data)
        
    @staticmethod
    def np2tensor(x):
        return torch.tensor(x, dtype=torch.float32)
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx]

# %%
latent_dims = 118
batch_size = 16
epochs = 1000

# %%
data_filename = 'data.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)
train_size = int(T * 0.8)
lr = 1e-1
scheduler = True
es_patience = 10

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Original Sensor Signal')
plt.show()

# %%
# read attack noise
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  6.33it/s]

# %%
noise_size = int(T * noise_percent)
norm_operation_win = 50
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for _type in noise_to_add_from:
    noise_id = random.sample(range(int(2 * T / 3)), 1)
    noises.append(Z_noise[_type][noise_id])
random.shuffle(noises)
if len(noises) > 0:
    noises = np.concatenate(noises, axis=0)
    # add noises to original sensor data Z
    Z[noise_time,:] = noises

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Noisy Sensor Signal')
plt.show()

# %%
Z_train, Z_test = Z[:train_size], Z[train_size:]
training = SensorDataset(Z_train)
test = SensorDataset(Z_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = VAETrainer(latent_dim=latent_dims, lr=lr, 
                     lr_scheduler=scheduler, es_patience=es_patience,
                     checkpoint_name=f'vae_{int(noise_percent*100)}%.pt', 
                     seed=seed)

# %%
summary(trainer.vae, (1, 358))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [1, 358]                  --
# ├─VariationalEncoder: 1-1                [1, 118]                  --
# │    └─Linear: 2-1                       [1, 236]                  84,724
# │    └─BatchNorm1d: 2-2                  [1, 236]                  472
# │    └─Linear: 2-3                       [1, 118]                  27,966
# │    └─Linear: 2-4                       [1, 118]                  14,042
# │    └─Linear: 2-5                       [1, 118]                  14,042
# ├─Decoder: 1-2                           [1, 358]                  --
# │    └─Linear: 2-6                       [1, 236]                  28,084
# │    └─BatchNorm1d: 2-7                  [1, 236]                  472
# │    └─Linear: 2-8                       [1, 358]                  84,846
# ==========================================================================================
# Total params: 254,648
# Trainable params: 254,648
# Non-trainable params: 0
# Total mult-adds (M): 0.25
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ==========================================================================================

# %%
vae, mse, kl, val_mse, val_kl = trainer.train(train_dl, test_dl, epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 1.5061], [KL: 1.1694], [Val_MSE: 0.1353], [Val_KL: 0.3652],
# Validation loss decreased (inf --> 0.135257).  Saving model ...
# Epoch 2/1000: [MSE: 0.1279], [KL: 0.3659], [Val_MSE: 0.1174], [Val_KL: 0.3904],
# Validation loss decreased (0.135257 --> 0.117406).  Saving model ...
# Epoch 3/1000: [MSE: 0.1195], [KL: 0.3648], [Val_MSE: 0.1251], [Val_KL: 0.3705],
# EarlyStopping counter: 1 out of 10
# Epoch 4/1000: [MSE: 0.1186], [KL: 0.3629], [Val_MSE: 0.1136], [Val_KL: 0.3731],
# Validation loss decreased (0.117406 --> 0.113617).  Saving model ...
# Epoch 5/1000: [MSE: 0.1088], [KL: 0.3614], [Val_MSE: 0.1139], [Val_KL: 0.3628],
# EarlyStopping counter: 1 out of 10
# Epoch 6/1000: [MSE: 0.1159], [KL: 0.3617], [Val_MSE: 0.1037], [Val_KL: 0.3649],
# Validation loss decreased (0.113617 --> 0.103653).  Saving model ...
# Epoch 7/1000: [MSE: 0.1080], [KL: 0.3604], [Val_MSE: 0.0965], [Val_KL: 0.3640],
# Validation loss decreased (0.103653 --> 0.096513).  Saving model ...
# Epoch 8/1000: [MSE: 0.1047], [KL: 0.3606], [Val_MSE: 0.1095], [Val_KL: 0.3623],
# EarlyStopping counter: 1 out of 10
# Epoch 9/1000: [MSE: 0.1112], [KL: 0.3609], [Val_MSE: 0.1023], [Val_KL: 0.3709],
# EarlyStopping counter: 2 out of 10
# Epoch 10/1000: [MSE: 0.1053], [KL: 0.3606], [Val_MSE: 0.0988], [Val_KL: 0.3634],
# EarlyStopping counter: 3 out of 10
# Epoch 11/1000: [MSE: 0.1081], [KL: 0.3609], [Val_MSE: 0.0983], [Val_KL: 0.3632],
# EarlyStopping counter: 4 out of 10
# Epoch 12/1000: [MSE: 0.1046], [KL: 0.3605], [Val_MSE: 0.1002], [Val_KL: 0.3631],
# EarlyStopping counter: 5 out of 10
# Epoch 13/1000: [MSE: 0.1038], [KL: 0.3608], [Val_MSE: 0.1030], [Val_KL: 0.3618],
# EarlyStopping counter: 6 out of 10
# Epoch 14/1000: [MSE: 0.1067], [KL: 0.3610], [Val_MSE: 0.1160], [Val_KL: 0.3648],
# EarlyStopping counter: 7 out of 10
# Epoch 15/1000: [MSE: 0.0980], [KL: 0.3593], [Val_MSE: 0.0903], [Val_KL: 0.3604],
# Validation loss decreased (0.096513 --> 0.090292).  Saving model ...
# Epoch 16/1000: [MSE: 0.0918], [KL: 0.3591], [Val_MSE: 0.0850], [Val_KL: 0.3621],
# Validation loss decreased (0.090292 --> 0.084986).  Saving model ...
# Epoch 17/1000: [MSE: 0.0932], [KL: 0.3593], [Val_MSE: 0.0848], [Val_KL: 0.3626],
# Validation loss decreased (0.084986 --> 0.084847).  Saving model ...
# Epoch 18/1000: [MSE: 0.0922], [KL: 0.3593], [Val_MSE: 0.0827], [Val_KL: 0.3627],
# Validation loss decreased (0.084847 --> 0.082736).  Saving model ...
# Epoch 19/1000: [MSE: 0.0922], [KL: 0.3593], [Val_MSE: 0.0882], [Val_KL: 0.3597],
# EarlyStopping counter: 1 out of 10
# Epoch 20/1000: [MSE: 0.0920], [KL: 0.3594], [Val_MSE: 0.0867], [Val_KL: 0.3615],
# EarlyStopping counter: 2 out of 10
# Epoch 21/1000: [MSE: 0.0919], [KL: 0.3596], [Val_MSE: 0.0876], [Val_KL: 0.3617],
# EarlyStopping counter: 3 out of 10
# Epoch 22/1000: [MSE: 0.0934], [KL: 0.3598], [Val_MSE: 0.0875], [Val_KL: 0.3608],
# EarlyStopping counter: 4 out of 10
# Epoch 23/1000: [MSE: 0.0931], [KL: 0.3591], [Val_MSE: 0.0826], [Val_KL: 0.3618],
# Validation loss decreased (0.082736 --> 0.082642).  Saving model ...
# Epoch 24/1000: [MSE: 0.0921], [KL: 0.3595], [Val_MSE: 0.0827], [Val_KL: 0.3614],
# EarlyStopping counter: 1 out of 10
# Epoch 25/1000: [MSE: 0.0911], [KL: 0.3594], [Val_MSE: 0.0863], [Val_KL: 0.3614],
# EarlyStopping counter: 2 out of 10
# Epoch 26/1000: [MSE: 0.0946], [KL: 0.3591], [Val_MSE: 0.0834], [Val_KL: 0.3620],
# EarlyStopping counter: 3 out of 10
# Epoch 27/1000: [MSE: 0.0921], [KL: 0.3591], [Val_MSE: 0.0869], [Val_KL: 0.3605],
# EarlyStopping counter: 4 out of 10
# Epoch 28/1000: [MSE: 0.0923], [KL: 0.3594], [Val_MSE: 0.0857], [Val_KL: 0.3608],
# EarlyStopping counter: 5 out of 10
# Epoch 29/1000: [MSE: 0.0928], [KL: 0.3594], [Val_MSE: 0.0842], [Val_KL: 0.3625],
# EarlyStopping counter: 6 out of 10
# Epoch 30/1000: [MSE: 0.0950], [KL: 0.3594], [Val_MSE: 0.0840], [Val_KL: 0.3623],
# EarlyStopping counter: 7 out of 10
# Epoch 31/1000: [MSE: 0.0910], [KL: 0.3590], [Val_MSE: 0.0821], [Val_KL: 0.3608],
# Validation loss decreased (0.082642 --> 0.082072).  Saving model ...
# Epoch 32/1000: [MSE: 0.0894], [KL: 0.3591], [Val_MSE: 0.0851], [Val_KL: 0.3603],
# EarlyStopping counter: 1 out of 10
# Epoch 33/1000: [MSE: 0.0900], [KL: 0.3593], [Val_MSE: 0.0812], [Val_KL: 0.3612],
# Validation loss decreased (0.082072 --> 0.081244).  Saving model ...
# Epoch 34/1000: [MSE: 0.0895], [KL: 0.3594], [Val_MSE: 0.0806], [Val_KL: 0.3614],
# Validation loss decreased (0.081244 --> 0.080560).  Saving model ...
# Epoch 35/1000: [MSE: 0.0920], [KL: 0.3589], [Val_MSE: 0.0843], [Val_KL: 0.3605],
# EarlyStopping counter: 1 out of 10
# Epoch 36/1000: [MSE: 0.0915], [KL: 0.3589], [Val_MSE: 0.0825], [Val_KL: 0.3612],
# EarlyStopping counter: 2 out of 10
# Epoch 37/1000: [MSE: 0.0903], [KL: 0.3592], [Val_MSE: 0.0822], [Val_KL: 0.3608],
# EarlyStopping counter: 3 out of 10
# Epoch 38/1000: [MSE: 0.0895], [KL: 0.3593], [Val_MSE: 0.0822], [Val_KL: 0.3616],
# EarlyStopping counter: 4 out of 10
# Epoch 39/1000: [MSE: 0.0888], [KL: 0.3592], [Val_MSE: 0.0810], [Val_KL: 0.3624],
# EarlyStopping counter: 5 out of 10
# Epoch 40/1000: [MSE: 0.0926], [KL: 0.3590], [Val_MSE: 0.0800], [Val_KL: 0.3623],
# Validation loss decreased (0.080560 --> 0.079964).  Saving model ...
# Epoch 41/1000: [MSE: 0.0885], [KL: 0.3592], [Val_MSE: 0.0836], [Val_KL: 0.3604],
# EarlyStopping counter: 1 out of 10
# Epoch 42/1000: [MSE: 0.0884], [KL: 0.3592], [Val_MSE: 0.0800], [Val_KL: 0.3622],
# EarlyStopping counter: 2 out of 10
# Epoch 43/1000: [MSE: 0.0924], [KL: 0.3592], [Val_MSE: 0.0824], [Val_KL: 0.3617],
# EarlyStopping counter: 3 out of 10
# Epoch 44/1000: [MSE: 0.0913], [KL: 0.3593], [Val_MSE: 0.0804], [Val_KL: 0.3625],
# EarlyStopping counter: 4 out of 10
# Epoch 45/1000: [MSE: 0.0898], [KL: 0.3592], [Val_MSE: 0.0814], [Val_KL: 0.3618],
# EarlyStopping counter: 5 out of 10
# Epoch 46/1000: [MSE: 0.0900], [KL: 0.3592], [Val_MSE: 0.0863], [Val_KL: 0.3599],
# EarlyStopping counter: 6 out of 10
# Epoch 47/1000: [MSE: 0.0913], [KL: 0.3594], [Val_MSE: 0.0815], [Val_KL: 0.3630],
# EarlyStopping counter: 7 out of 10
# Epoch 48/1000: [MSE: 0.0891], [KL: 0.3589], [Val_MSE: 0.0813], [Val_KL: 0.3611],
# EarlyStopping counter: 8 out of 10
# Epoch 49/1000: [MSE: 0.0904], [KL: 0.3590], [Val_MSE: 0.0814], [Val_KL: 0.3607],
# EarlyStopping counter: 9 out of 10
# Epoch 50/1000: [MSE: 0.0882], [KL: 0.3591], [Val_MSE: 0.0811], [Val_KL: 0.3613],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, kl, val_mse, val_kl):
    fig, axs = plt.subplots(1,2, figsize=(10,4))
    axs[0].plot(mse, color='r', label='Training')
    axs[0].plot(val_mse, color='b', label='Validation')
    axs[0].set_title('MSE Loss')
    axs[1].plot(kl, color='r', label='Training')
    axs[1].plot(val_kl, color='b', label='Validation')
    axs[1].set_title('KL Loss')
    plt.legend()
    #plt.savefig('./imgMix/mse-kl-mvae.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, kl, val_mse, val_kl)

# %%
vae.eval()
Z = torch.tensor(Z, dtype=torch.float32).to(device)
Z_enc = vae(Z)

# %%
idx = 1001
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z[idx,:].cpu().detach().numpy()), label='Original')
axs.plot(np.transpose(Z_enc[idx,:].cpu().detach().numpy()), label='Reconstructed')
axs.set_title('Original vs. Reconstructed Signals')
plt.legend()
plt.show()

# %%
vae.eval()
Z_latent = vae.encoder(Z)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(Z_latent.cpu().detach().numpy()))
axs[0].set_title('Latent Noisy Sensor Signal')
axs[1].plot(np.transpose(Z_enc.cpu().detach().numpy()))
axs[1].set_title('Recunstructed Noisy Sensor Signal')
axs[2].plot(np.transpose(Z.cpu().detach().numpy()))
axs[2].set_title('Original Noisy Sensor Signal')
plt.show()

# %% [markdown]
# **$t=101$ latent distribution**

# %%
vae.eval()
sample_size = 30
signal = Z[100:102]
signal_latent, signal_rec = [], []
for _ in range(sample_size):
    signal_rec.append(vae(signal))
    signal_latent.append(vae.encoder(signal))
signal_latent = torch.stack(signal_latent, dim=0)
signal_rec = torch.stack(signal_rec, dim=0)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(signal_latent.cpu().detach().numpy()[:,0,:]))
axs[0].set_title(r'Latent Noisy Sensor Signal for $t=101$')
axs[1].plot(np.transpose(signal_rec.cpu().detach().numpy()[:,0,:]))
axs[1].set_title(r'Recunstructed Noisy Sensor Signal for $t=101$')
axs[2].plot(np.transpose(signal.cpu().detach().numpy()[0]))
axs[2].set_title(r'Original Noisy Sensor Signal for $t=101$')
plt.show()

# %%
noise_type = 7
noise_percent = 0.1

# %%
import re
import os
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae_trainer import VAETrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')

# %%
seed = 37
torch.manual_seed(seed)

# %%
class SensorDataset():
    def __init__(self, data: np.array):
        self.x = self.np2tensor(data)
        
    @staticmethod
    def np2tensor(x):
        return torch.tensor(x, dtype=torch.float32)
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx]

# %%
latent_dims = 118
batch_size = 16
epochs = 1000

# %%
data_filename = 'data.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)
train_size = int(T * 0.8)
lr = 1e-1
scheduler = True
es_patience = 10

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Original Sensor Signal')
plt.show()

# %%
noise_size = int(T * noise_percent)
norm_operation_win = 50

# %%
# read attack noise
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  6.58it/s]

# %%
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for type in noise_to_add_from:
    noise_id = random.sample(range(T), 1)
    noises.append(Z_noise[type][noise_id])
random.shuffle(noises)
noises = np.concatenate(noises, axis=0)
# add noises to original sensor data Z
Z[noise_time] = noises

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Noisy Sensor Signal')
plt.show()

# %%
Z_train, Z_test = Z[:train_size], Z[train_size:]
training = SensorDataset(Z_train)
test = SensorDataset(Z_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = VAETrainer(latent_dim=latent_dims, lr=lr, 
                     lr_scheduler=scheduler, es_patience=es_patience,
                     checkpoint_name='vae_10%.pt', seed=seed)
# Out:
# Device:  cpu

# %%
summary(trainer.vae, (1, 358))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [1, 358]                  --
# ├─VariationalEncoder: 1-1                [1, 118]                  --
# │    └─Linear: 2-1                       [1, 236]                  84,724
# │    └─BatchNorm1d: 2-2                  [1, 236]                  472
# │    └─Linear: 2-3                       [1, 118]                  27,966
# │    └─Linear: 2-4                       [1, 118]                  14,042
# │    └─Linear: 2-5                       [1, 118]                  14,042
# ├─Decoder: 1-2                           [1, 358]                  --
# │    └─Linear: 2-6                       [1, 236]                  28,084
# │    └─BatchNorm1d: 2-7                  [1, 236]                  472
# │    └─Linear: 2-8                       [1, 358]                  84,846
# ==========================================================================================
# Total params: 254,648
# Trainable params: 254,648
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.25
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ==========================================================================================

# %%
vae, mse, kl, val_mse, val_kl = trainer.train(train_dl, test_dl, epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 1.6651], [KL: 1.1807], [Val_MSE: 0.1868], [Val_KL: 0.3622],
# Validation loss decreased (inf --> 0.186822).  Saving model ...
# Epoch 2/1000: [MSE: 0.1152], [KL: 0.3689], [Val_MSE: 0.1323], [Val_KL: 0.3703],
# Validation loss decreased (0.186822 --> 0.132287).  Saving model ...
# Epoch 3/1000: [MSE: 0.1022], [KL: 0.3705], [Val_MSE: 0.1035], [Val_KL: 0.3751],
# Validation loss decreased (0.132287 --> 0.103469).  Saving model ...
# Epoch 4/1000: [MSE: 0.1029], [KL: 0.3717], [Val_MSE: 0.0974], [Val_KL: 0.3727],
# Validation loss decreased (0.103469 --> 0.097429).  Saving model ...
# Epoch 5/1000: [MSE: 0.0923], [KL: 0.3697], [Val_MSE: 0.0888], [Val_KL: 0.3670],
# Validation loss decreased (0.097429 --> 0.088774).  Saving model ...
# Epoch 6/1000: [MSE: 0.0921], [KL: 0.3685], [Val_MSE: 0.0988], [Val_KL: 0.3704],
# EarlyStopping counter: 1 out of 10
# Epoch 7/1000: [MSE: 0.0905], [KL: 0.3682], [Val_MSE: 0.1021], [Val_KL: 0.3653],
# EarlyStopping counter: 2 out of 10
# Epoch 8/1000: [MSE: 0.0978], [KL: 0.3702], [Val_MSE: 0.3044], [Val_KL: 0.3777],
# EarlyStopping counter: 3 out of 10
# Epoch 9/1000: [MSE: 0.0916], [KL: 0.3697], [Val_MSE: 0.0892], [Val_KL: 0.3728],
# EarlyStopping counter: 4 out of 10
# Epoch 10/1000: [MSE: 0.0899], [KL: 0.3692], [Val_MSE: 0.0881], [Val_KL: 0.3672],
# Validation loss decreased (0.088774 --> 0.088100).  Saving model ...
# Epoch 11/1000: [MSE: 0.0925], [KL: 0.3690], [Val_MSE: 0.0831], [Val_KL: 0.3771],
# Validation loss decreased (0.088100 --> 0.083053).  Saving model ...
# Epoch 12/1000: [MSE: 0.0941], [KL: 0.3691], [Val_MSE: 0.1259], [Val_KL: 0.3871],
# EarlyStopping counter: 1 out of 10
# Epoch 13/1000: [MSE: 0.0946], [KL: 0.3684], [Val_MSE: 0.0987], [Val_KL: 0.3668],
# EarlyStopping counter: 2 out of 10
# Epoch 14/1000: [MSE: 0.0935], [KL: 0.3683], [Val_MSE: 0.1035], [Val_KL: 0.3655],
# EarlyStopping counter: 3 out of 10
# Epoch 15/1000: [MSE: 0.0944], [KL: 0.3691], [Val_MSE: 0.0799], [Val_KL: 0.3700],
# Validation loss decreased (0.083053 --> 0.079931).  Saving model ...
# Epoch 16/1000: [MSE: 0.0888], [KL: 0.3692], [Val_MSE: 0.0801], [Val_KL: 0.3671],
# EarlyStopping counter: 1 out of 10
# Epoch 17/1000: [MSE: 0.0901], [KL: 0.3690], [Val_MSE: 0.0886], [Val_KL: 0.3661],
# EarlyStopping counter: 2 out of 10
# Epoch 18/1000: [MSE: 0.0925], [KL: 0.3694], [Val_MSE: 0.1399], [Val_KL: 0.3701],
# EarlyStopping counter: 3 out of 10
# Epoch 19/1000: [MSE: 0.0932], [KL: 0.3691], [Val_MSE: 0.0924], [Val_KL: 0.3682],
# EarlyStopping counter: 4 out of 10
# Epoch 20/1000: [MSE: 0.0944], [KL: 0.3688], [Val_MSE: 0.0901], [Val_KL: 0.3734],
# EarlyStopping counter: 5 out of 10
# Epoch 21/1000: [MSE: 0.0953], [KL: 0.3692], [Val_MSE: 0.1120], [Val_KL: 0.3671],
# EarlyStopping counter: 6 out of 10
# Epoch 22/1000: [MSE: 0.0978], [KL: 0.3702], [Val_MSE: 0.1173], [Val_KL: 0.3638],
# EarlyStopping counter: 7 out of 10
# Epoch 23/1000: [MSE: 0.0785], [KL: 0.3656], [Val_MSE: 0.0779], [Val_KL: 0.3673],
# Validation loss decreased (0.079931 --> 0.077920).  Saving model ...
# Epoch 24/1000: [MSE: 0.0764], [KL: 0.3662], [Val_MSE: 0.0696], [Val_KL: 0.3673],
# Validation loss decreased (0.077920 --> 0.069581).  Saving model ...
# Epoch 25/1000: [MSE: 0.0758], [KL: 0.3661], [Val_MSE: 0.0721], [Val_KL: 0.3669],
# EarlyStopping counter: 1 out of 10
# Epoch 26/1000: [MSE: 0.0758], [KL: 0.3664], [Val_MSE: 0.0969], [Val_KL: 0.3678],
# EarlyStopping counter: 2 out of 10
# Epoch 27/1000: [MSE: 0.0754], [KL: 0.3658], [Val_MSE: 0.0682], [Val_KL: 0.3679],
# Validation loss decreased (0.069581 --> 0.068236).  Saving model ...
# Epoch 28/1000: [MSE: 0.0747], [KL: 0.3666], [Val_MSE: 0.0676], [Val_KL: 0.3685],
# Validation loss decreased (0.068236 --> 0.067585).  Saving model ...
# Epoch 29/1000: [MSE: 0.0742], [KL: 0.3665], [Val_MSE: 0.0693], [Val_KL: 0.3686],
# EarlyStopping counter: 1 out of 10
# Epoch 30/1000: [MSE: 0.0758], [KL: 0.3665], [Val_MSE: 0.0679], [Val_KL: 0.3677],
# EarlyStopping counter: 2 out of 10
# Epoch 31/1000: [MSE: 0.0749], [KL: 0.3669], [Val_MSE: 0.0672], [Val_KL: 0.3676],
# Validation loss decreased (0.067585 --> 0.067191).  Saving model ...
# Epoch 32/1000: [MSE: 0.0705], [KL: 0.3673], [Val_MSE: 0.0711], [Val_KL: 0.3682],
# EarlyStopping counter: 1 out of 10
# Epoch 33/1000: [MSE: 0.0732], [KL: 0.3674], [Val_MSE: 0.0641], [Val_KL: 0.3694],
# Validation loss decreased (0.067191 --> 0.064146).  Saving model ...
# Epoch 34/1000: [MSE: 0.0732], [KL: 0.3675], [Val_MSE: 0.0738], [Val_KL: 0.3676],
# EarlyStopping counter: 1 out of 10
# Epoch 35/1000: [MSE: 0.0704], [KL: 0.3673], [Val_MSE: 0.0694], [Val_KL: 0.3673],
# EarlyStopping counter: 2 out of 10
# Epoch 36/1000: [MSE: 0.0718], [KL: 0.3676], [Val_MSE: 0.0679], [Val_KL: 0.3685],
# EarlyStopping counter: 3 out of 10
# Epoch 37/1000: [MSE: 0.0707], [KL: 0.3677], [Val_MSE: 0.0681], [Val_KL: 0.3680],
# EarlyStopping counter: 4 out of 10
# Epoch 38/1000: [MSE: 0.0683], [KL: 0.3674], [Val_MSE: 0.0637], [Val_KL: 0.3678],
# Validation loss decreased (0.064146 --> 0.063716).  Saving model ...
# Epoch 39/1000: [MSE: 0.0683], [KL: 0.3673], [Val_MSE: 0.0670], [Val_KL: 0.3696],
# EarlyStopping counter: 1 out of 10
# Epoch 40/1000: [MSE: 0.0688], [KL: 0.3676], [Val_MSE: 0.0663], [Val_KL: 0.3690],
# EarlyStopping counter: 2 out of 10
# Epoch 41/1000: [MSE: 0.0703], [KL: 0.3671], [Val_MSE: 0.0699], [Val_KL: 0.3675],
# EarlyStopping counter: 3 out of 10
# Epoch 42/1000: [MSE: 0.0709], [KL: 0.3674], [Val_MSE: 0.0656], [Val_KL: 0.3684],
# EarlyStopping counter: 4 out of 10
# Epoch 43/1000: [MSE: 0.0702], [KL: 0.3676], [Val_MSE: 0.0685], [Val_KL: 0.3684],
# EarlyStopping counter: 5 out of 10
# Epoch 44/1000: [MSE: 0.0690], [KL: 0.3679], [Val_MSE: 0.0643], [Val_KL: 0.3712],
# EarlyStopping counter: 6 out of 10
# Epoch 45/1000: [MSE: 0.0681], [KL: 0.3677], [Val_MSE: 0.0647], [Val_KL: 0.3694],
# EarlyStopping counter: 7 out of 10
# Epoch 46/1000: [MSE: 0.0672], [KL: 0.3675], [Val_MSE: 0.0663], [Val_KL: 0.3666],
# EarlyStopping counter: 8 out of 10
# Epoch 47/1000: [MSE: 0.0672], [KL: 0.3672], [Val_MSE: 0.0605], [Val_KL: 0.3683],
# Validation loss decreased (0.063716 --> 0.060467).  Saving model ...
# Epoch 48/1000: [MSE: 0.0632], [KL: 0.3671], [Val_MSE: 0.0644], [Val_KL: 0.3667],
# EarlyStopping counter: 1 out of 10
# Epoch 49/1000: [MSE: 0.0672], [KL: 0.3672], [Val_MSE: 0.0629], [Val_KL: 0.3673],
# EarlyStopping counter: 2 out of 10
# Epoch 50/1000: [MSE: 0.0653], [KL: 0.3670], [Val_MSE: 0.0584], [Val_KL: 0.3688],
# Validation loss decreased (0.060467 --> 0.058380).  Saving model ...
# Epoch 51/1000: [MSE: 0.0669], [KL: 0.3672], [Val_MSE: 0.0619], [Val_KL: 0.3677],
# EarlyStopping counter: 1 out of 10
# Epoch 52/1000: [MSE: 0.0670], [KL: 0.3673], [Val_MSE: 0.0606], [Val_KL: 0.3680],
# EarlyStopping counter: 2 out of 10
# Epoch 53/1000: [MSE: 0.0655], [KL: 0.3673], [Val_MSE: 0.0637], [Val_KL: 0.3673],
# EarlyStopping counter: 3 out of 10
# Epoch 54/1000: [MSE: 0.0653], [KL: 0.3670], [Val_MSE: 0.0621], [Val_KL: 0.3672],
# EarlyStopping counter: 4 out of 10
# Epoch 55/1000: [MSE: 0.0643], [KL: 0.3676], [Val_MSE: 0.0612], [Val_KL: 0.3681],
# EarlyStopping counter: 5 out of 10
# Epoch 56/1000: [MSE: 0.0663], [KL: 0.3674], [Val_MSE: 0.0621], [Val_KL: 0.3684],
# EarlyStopping counter: 6 out of 10
# Epoch 57/1000: [MSE: 0.0656], [KL: 0.3676], [Val_MSE: 0.0627], [Val_KL: 0.3671],
# EarlyStopping counter: 7 out of 10
# Epoch 58/1000: [MSE: 0.0646], [KL: 0.3674], [Val_MSE: 0.0613], [Val_KL: 0.3682],
# EarlyStopping counter: 8 out of 10
# Epoch 59/1000: [MSE: 0.0661], [KL: 0.3675], [Val_MSE: 0.0595], [Val_KL: 0.3685],
# EarlyStopping counter: 9 out of 10
# Epoch 60/1000: [MSE: 0.0666], [KL: 0.3676], [Val_MSE: 0.0634], [Val_KL: 0.3671],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, kl, val_mse, val_kl):
    fig, axs = plt.subplots(2, figsize=(8,12))
    axs[0].plot(mse, color='r', label='Training')
    axs[0].plot(val_mse, color='b', label='Validation')
    axs[0].set_title('MSE Loss')
    axs[1].plot(kl, color='r', label='Training')
    axs[1].plot(val_kl, color='b', label='Validation')
    axs[1].set_title('KL Loss')
    plt.legend()
    #plt.savefig('./imgMix/mse-kl-mvae.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, kl, val_mse, val_kl)

# %%
vae.eval()
Z = torch.tensor(Z, dtype=torch.float32)
Z_enc = vae(Z)

# %%
idx = 1001
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z[idx,:].cpu().detach().numpy()), label='Original')
axs.plot(np.transpose(Z_enc[idx,:].cpu().detach().numpy()), label='Reconstructed')
axs.set_title('Original vs. Reconstructed Signals')
plt.legend()
plt.show()

# %%
vae.eval()
Z_latent = vae.encoder(Z)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(Z_latent.cpu().detach().numpy()))
axs[0].set_title('Latent Noisy Sensor Signal')
axs[1].plot(np.transpose(Z_enc.cpu().detach().numpy()))
axs[1].set_title('Recunstructed Noisy Sensor Signal')
axs[2].plot(np.transpose(Z.cpu().detach().numpy()))
axs[2].set_title('Original Noisy Sensor Signal')
plt.show()

# %% [markdown]
# **$t=1$ latent distribution**

# %%
vae.eval()
sample_size = 30
signal = Z[0:2]
signal_latent, signal_rec = [], []
for _ in range(sample_size):
    signal_rec.append(vae(signal))
    signal_latent.append(vae.encoder(signal))
signal_latent = torch.stack(signal_latent, dim=0)
signal_rec = torch.stack(signal_rec, dim=0)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(signal_latent.cpu().detach().numpy()[:,0,:]))
axs[0].set_title('Latent Sensor Signal')
axs[1].plot(np.transpose(signal_rec.cpu().detach().numpy()[:,0,:]))
axs[1].set_title('Recunstructed Sensor Signal')
axs[2].plot(np.transpose(signal.cpu().detach().numpy()[0]))
axs[2].set_title('Original Sensor Signal')
plt.show()

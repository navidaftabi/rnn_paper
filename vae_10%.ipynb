# %%
noise_type = 7
noise_percent = 0.1

# %%
import re
import os
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae_trainer import VAETrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')

# %%
seed = 37
torch.manual_seed(seed)

# %%
class SensorDataset():
    def __init__(self, data: np.array):
        self.x = self.np2tensor(data)
        
    @staticmethod
    def np2tensor(x):
        return torch.tensor(x, dtype=torch.float32)
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx]

# %%
latent_dims = 118
batch_size = 16
epochs = 1000

# %%
data_filename = 'data.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)
train_size = int(T * 0.8)
lr = 1e-1
scheduler = True
es_patience = 10

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Original Sensor Signal')
plt.show()

# %%
noise_size = int(T * noise_percent)
norm_operation_win = 50

# %%
# read attack noise
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  6.51it/s]

# %%
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for type in noise_to_add_from:
    noise_id = random.sample(range(T), 1)
    noises.append(Z_noise[type][noise_id])
random.shuffle(noises)
noises = np.concatenate(noises, axis=0)
# add noises to original sensor data Z
Z[noise_time] = noises

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Noisy Sensor Signal')
plt.show()

# %%
Z_train, Z_test = Z[:train_size], Z[train_size:]
training = SensorDataset(Z_train)
test = SensorDataset(Z_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = VAETrainer(latent_dim=latent_dims, lr=lr, 
                     lr_scheduler=scheduler, es_patience=es_patience,
                     checkpoint_name='vae_10%.pt', seed=seed)
# Out:
# Device:  cpu

# %%
summary(trainer.vae, (1, 358))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [1, 358]                  --
# ├─VariationalEncoder: 1-1                [1, 118]                  --
# │    └─Linear: 2-1                       [1, 236]                  84,724
# │    └─BatchNorm1d: 2-2                  [1, 236]                  472
# │    └─Linear: 2-3                       [1, 118]                  27,966
# │    └─Linear: 2-4                       [1, 118]                  14,042
# │    └─Linear: 2-5                       [1, 118]                  14,042
# ├─Decoder: 1-2                           [1, 358]                  --
# │    └─Linear: 2-6                       [1, 236]                  28,084
# │    └─BatchNorm1d: 2-7                  [1, 236]                  472
# │    └─Linear: 2-8                       [1, 358]                  84,846
# ==========================================================================================
# Total params: 254,648
# Trainable params: 254,648
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.25
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ==========================================================================================

# %%
vae, mse, kl, val_mse, val_kl = trainer.train(train_dl, test_dl, epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 2.0245], [KL: 1.0778], [Val_MSE: 0.1552], [Val_KL: 0.3617],
# Validation loss decreased (inf --> 0.155185).  Saving model ...
# Epoch 2/1000: [MSE: 0.1178], [KL: 0.3664], [Val_MSE: 0.1188], [Val_KL: 0.3668],
# Validation loss decreased (0.155185 --> 0.118817).  Saving model ...
# Epoch 3/1000: [MSE: 0.1115], [KL: 0.3641], [Val_MSE: 0.1144], [Val_KL: 0.3673],
# Validation loss decreased (0.118817 --> 0.114388).  Saving model ...
# Epoch 4/1000: [MSE: 0.1154], [KL: 0.3631], [Val_MSE: 0.1046], [Val_KL: 0.3643],
# Validation loss decreased (0.114388 --> 0.104615).  Saving model ...
# Epoch 5/1000: [MSE: 0.1138], [KL: 0.3637], [Val_MSE: 0.1114], [Val_KL: 0.3643],
# EarlyStopping counter: 1 out of 10
# Epoch 6/1000: [MSE: 0.1164], [KL: 0.3626], [Val_MSE: 0.1410], [Val_KL: 0.3606],
# EarlyStopping counter: 2 out of 10
# Epoch 7/1000: [MSE: 0.1098], [KL: 0.3625], [Val_MSE: 0.1111], [Val_KL: 0.3605],
# EarlyStopping counter: 3 out of 10
# Epoch 8/1000: [MSE: 0.1094], [KL: 0.3598], [Val_MSE: 0.1755], [Val_KL: 0.3601],
# EarlyStopping counter: 4 out of 10
# Epoch 9/1000: [MSE: 0.1058], [KL: 0.3602], [Val_MSE: 0.1071], [Val_KL: 0.3602],
# EarlyStopping counter: 5 out of 10
# Epoch 10/1000: [MSE: 0.1033], [KL: 0.3594], [Val_MSE: 0.0996], [Val_KL: 0.3591],
# Validation loss decreased (0.104615 --> 0.099568).  Saving model ...
# Epoch 11/1000: [MSE: 0.1052], [KL: 0.3595], [Val_MSE: 0.0939], [Val_KL: 0.3597],
# Validation loss decreased (0.099568 --> 0.093929).  Saving model ...
# Epoch 12/1000: [MSE: 0.1064], [KL: 0.3591], [Val_MSE: 0.0952], [Val_KL: 0.3615],
# EarlyStopping counter: 1 out of 10
# Epoch 13/1000: [MSE: 0.1051], [KL: 0.3598], [Val_MSE: 0.0982], [Val_KL: 0.3609],
# EarlyStopping counter: 2 out of 10
# Epoch 14/1000: [MSE: 0.1055], [KL: 0.3596], [Val_MSE: 0.1035], [Val_KL: 0.3602],
# EarlyStopping counter: 3 out of 10
# Epoch 15/1000: [MSE: 0.1048], [KL: 0.3596], [Val_MSE: 0.0824], [Val_KL: 0.3619],
# Validation loss decreased (0.093929 --> 0.082408).  Saving model ...
# Epoch 16/1000: [MSE: 0.1018], [KL: 0.3597], [Val_MSE: 0.0945], [Val_KL: 0.3597],
# EarlyStopping counter: 1 out of 10
# Epoch 17/1000: [MSE: 0.1010], [KL: 0.3593], [Val_MSE: 0.0902], [Val_KL: 0.3599],
# EarlyStopping counter: 2 out of 10
# Epoch 18/1000: [MSE: 0.1045], [KL: 0.3593], [Val_MSE: 0.0831], [Val_KL: 0.3620],
# EarlyStopping counter: 3 out of 10
# Epoch 19/1000: [MSE: 0.1046], [KL: 0.3598], [Val_MSE: 0.0926], [Val_KL: 0.3610],
# EarlyStopping counter: 4 out of 10
# Epoch 20/1000: [MSE: 0.1040], [KL: 0.3596], [Val_MSE: 0.1061], [Val_KL: 0.3601],
# EarlyStopping counter: 5 out of 10
# Epoch 21/1000: [MSE: 0.1032], [KL: 0.3593], [Val_MSE: 0.1112], [Val_KL: 0.3575],
# EarlyStopping counter: 6 out of 10
# Epoch 22/1000: [MSE: 0.1066], [KL: 0.3595], [Val_MSE: 0.1110], [Val_KL: 0.3613],
# EarlyStopping counter: 7 out of 10
# Epoch 23/1000: [MSE: 0.0940], [KL: 0.3587], [Val_MSE: 0.0799], [Val_KL: 0.3598],
# Validation loss decreased (0.082408 --> 0.079857).  Saving model ...
# Epoch 24/1000: [MSE: 0.0914], [KL: 0.3588], [Val_MSE: 0.0808], [Val_KL: 0.3587],
# EarlyStopping counter: 1 out of 10
# Epoch 25/1000: [MSE: 0.0914], [KL: 0.3585], [Val_MSE: 0.0809], [Val_KL: 0.3590],
# EarlyStopping counter: 2 out of 10
# Epoch 26/1000: [MSE: 0.0929], [KL: 0.3585], [Val_MSE: 0.0863], [Val_KL: 0.3594],
# EarlyStopping counter: 3 out of 10
# Epoch 27/1000: [MSE: 0.0911], [KL: 0.3585], [Val_MSE: 0.0828], [Val_KL: 0.3588],
# EarlyStopping counter: 4 out of 10
# Epoch 28/1000: [MSE: 0.0906], [KL: 0.3583], [Val_MSE: 0.0828], [Val_KL: 0.3590],
# EarlyStopping counter: 5 out of 10
# Epoch 29/1000: [MSE: 0.0914], [KL: 0.3582], [Val_MSE: 0.0830], [Val_KL: 0.3587],
# EarlyStopping counter: 6 out of 10
# Epoch 30/1000: [MSE: 0.0954], [KL: 0.3580], [Val_MSE: 0.0806], [Val_KL: 0.3589],
# EarlyStopping counter: 7 out of 10
# Epoch 31/1000: [MSE: 0.0905], [KL: 0.3578], [Val_MSE: 0.0801], [Val_KL: 0.3575],
# EarlyStopping counter: 8 out of 10
# Epoch 32/1000: [MSE: 0.0889], [KL: 0.3578], [Val_MSE: 0.0799], [Val_KL: 0.3586],
# EarlyStopping counter: 9 out of 10
# Epoch 33/1000: [MSE: 0.0929], [KL: 0.3579], [Val_MSE: 0.0822], [Val_KL: 0.3580],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, kl, val_mse, val_kl):
    fig, axs = plt.subplots(2, figsize=(8,12))
    axs[0].plot(mse, color='r', label='Training')
    axs[0].plot(val_mse, color='b', label='Validation')
    axs[0].set_title('MSE Loss')
    axs[1].plot(kl, color='r', label='Training')
    axs[1].plot(val_kl, color='b', label='Validation')
    axs[1].set_title('KL Loss')
    plt.legend()
    #plt.savefig('./imgMix/mse-kl-mvae.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, kl, val_mse, val_kl)

# %%
vae.eval()
Z = torch.tensor(Z, dtype=torch.float32)
Z_enc = vae(Z)

# %%
idx = 1001
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z[idx,:].cpu().detach().numpy()), label='Original')
axs.plot(np.transpose(Z_enc[idx,:].cpu().detach().numpy()), label='Reconstructed')
axs.set_title('Original vs. Reconstructed Signals')
plt.legend()
plt.show()

# %%
vae.eval()
Z_latent = vae.encoder(Z)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(Z_latent.cpu().detach().numpy()))
axs[0].set_title('Latent Noisy Sensor Signal')
axs[1].plot(np.transpose(Z_enc.cpu().detach().numpy()))
axs[1].set_title('Recunstructed Noisy Sensor Signal')
axs[2].plot(np.transpose(Z.cpu().detach().numpy()))
axs[2].set_title('Original Noisy Sensor Signal')
plt.show()

# %%
noise_type = 7
noise_percent = 0.10

# %%
import re
import os
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae_trainer import VAETrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')

# %%
seed = 37
torch.manual_seed(seed)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class SensorDataset():
    def __init__(self, data: np.array):
        self.x = self.np2tensor(data)
        
    @staticmethod
    def np2tensor(x):
        return torch.tensor(x, dtype=torch.float32)
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx]

# %%
latent_dims = 118
batch_size = 16
epochs = 1000

# %%
data_filename = 'data.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)
train_size = int(T * 0.8)
lr = 1e-1
scheduler = True
es_patience = 10

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Original Sensor Signal')
plt.show()

# %%
# read attack noise
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  6.36it/s]

# %%
noise_size = int(T * noise_percent)
norm_operation_win = 50
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for type in noise_to_add_from:
    noise_id = random.sample(range(T), 1)
    noises.append(Z_noise[type][noise_id])
random.shuffle(noises)
noises = np.concatenate(noises, axis=0)
# add noises to original sensor data Z
Z[noise_time,:] = noises

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Noisy Sensor Signal')
plt.show()

# %%
Z_train, Z_test = Z[:train_size], Z[train_size:]
training = SensorDataset(Z_train)
test = SensorDataset(Z_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = VAETrainer(latent_dim=latent_dims, lr=lr, 
                     lr_scheduler=scheduler, es_patience=es_patience,
                     checkpoint_name=f'vae_{int(noise_percent * 100)}%.pt', 
                     seed=seed)
# Out:
# Device:  cuda

# %%
summary(trainer.vae, (1, 358))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [1, 358]                  --
# ├─VariationalEncoder: 1-1                [1, 118]                  --
# │    └─Linear: 2-1                       [1, 236]                  84,724
# │    └─BatchNorm1d: 2-2                  [1, 236]                  472
# │    └─Linear: 2-3                       [1, 118]                  27,966
# │    └─Linear: 2-4                       [1, 118]                  14,042
# │    └─Linear: 2-5                       [1, 118]                  14,042
# ├─Decoder: 1-2                           [1, 358]                  --
# │    └─Linear: 2-6                       [1, 236]                  28,084
# │    └─BatchNorm1d: 2-7                  [1, 236]                  472
# │    └─Linear: 2-8                       [1, 358]                  84,846
# ==========================================================================================
# Total params: 254,648
# Trainable params: 254,648
# Non-trainable params: 0
# Total mult-adds (M): 0.25
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ==========================================================================================

# %%
vae, mse, kl, val_mse, val_kl = trainer.train(train_dl, test_dl, epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 1.4809], [KL: 1.0663], [Val_MSE: 0.1050], [Val_KL: 0.3853],
# Validation loss decreased (inf --> 0.105035).  Saving model ...
# Epoch 2/1000: [MSE: 0.1081], [KL: 0.3700], [Val_MSE: 0.1131], [Val_KL: 0.3917],
# EarlyStopping counter: 1 out of 10
# Epoch 3/1000: [MSE: 0.0963], [KL: 0.3693], [Val_MSE: 0.0827], [Val_KL: 0.3714],
# Validation loss decreased (0.105035 --> 0.082660).  Saving model ...
# Epoch 4/1000: [MSE: 0.0968], [KL: 0.3686], [Val_MSE: 0.0850], [Val_KL: 0.3845],
# EarlyStopping counter: 1 out of 10
# Epoch 5/1000: [MSE: 0.0924], [KL: 0.3687], [Val_MSE: 0.0956], [Val_KL: 0.3638],
# EarlyStopping counter: 2 out of 10
# Epoch 6/1000: [MSE: 0.0947], [KL: 0.3683], [Val_MSE: 0.0877], [Val_KL: 0.3772],
# EarlyStopping counter: 3 out of 10
# Epoch 7/1000: [MSE: 0.0922], [KL: 0.3672], [Val_MSE: 0.1118], [Val_KL: 0.3850],
# EarlyStopping counter: 4 out of 10
# Epoch 8/1000: [MSE: 0.0917], [KL: 0.3676], [Val_MSE: 0.0933], [Val_KL: 0.3636],
# EarlyStopping counter: 5 out of 10
# Epoch 9/1000: [MSE: 0.0929], [KL: 0.3671], [Val_MSE: 0.1036], [Val_KL: 0.3644],
# EarlyStopping counter: 6 out of 10
# Epoch 10/1000: [MSE: 0.0909], [KL: 0.3677], [Val_MSE: 0.0827], [Val_KL: 0.3675],
# EarlyStopping counter: 7 out of 10
# Epoch 11/1000: [MSE: 0.0779], [KL: 0.3660], [Val_MSE: 0.0757], [Val_KL: 0.3644],
# Validation loss decreased (0.082660 --> 0.075714).  Saving model ...
# Epoch 12/1000: [MSE: 0.0776], [KL: 0.3660], [Val_MSE: 0.0700], [Val_KL: 0.3680],
# Validation loss decreased (0.075714 --> 0.069954).  Saving model ...
# Epoch 13/1000: [MSE: 0.0779], [KL: 0.3661], [Val_MSE: 0.0704], [Val_KL: 0.3680],
# EarlyStopping counter: 1 out of 10
# Epoch 14/1000: [MSE: 0.0772], [KL: 0.3663], [Val_MSE: 0.0693], [Val_KL: 0.3702],
# Validation loss decreased (0.069954 --> 0.069271).  Saving model ...
# Epoch 15/1000: [MSE: 0.0785], [KL: 0.3661], [Val_MSE: 0.0704], [Val_KL: 0.3667],
# EarlyStopping counter: 1 out of 10
# Epoch 16/1000: [MSE: 0.0767], [KL: 0.3659], [Val_MSE: 0.0721], [Val_KL: 0.3670],
# EarlyStopping counter: 2 out of 10
# Epoch 17/1000: [MSE: 0.0755], [KL: 0.3662], [Val_MSE: 0.0718], [Val_KL: 0.3701],
# EarlyStopping counter: 3 out of 10
# Epoch 18/1000: [MSE: 0.0751], [KL: 0.3665], [Val_MSE: 0.0723], [Val_KL: 0.3718],
# EarlyStopping counter: 4 out of 10
# Epoch 19/1000: [MSE: 0.0769], [KL: 0.3661], [Val_MSE: 0.0674], [Val_KL: 0.3687],
# Validation loss decreased (0.069271 --> 0.067406).  Saving model ...
# Epoch 20/1000: [MSE: 0.0760], [KL: 0.3663], [Val_MSE: 0.0699], [Val_KL: 0.3660],
# EarlyStopping counter: 1 out of 10
# Epoch 21/1000: [MSE: 0.0750], [KL: 0.3663], [Val_MSE: 0.0683], [Val_KL: 0.3676],
# EarlyStopping counter: 2 out of 10
# Epoch 22/1000: [MSE: 0.0763], [KL: 0.3661], [Val_MSE: 0.0695], [Val_KL: 0.3692],
# EarlyStopping counter: 3 out of 10
# Epoch 23/1000: [MSE: 0.0775], [KL: 0.3659], [Val_MSE: 0.0753], [Val_KL: 0.3641],
# EarlyStopping counter: 4 out of 10
# Epoch 24/1000: [MSE: 0.0757], [KL: 0.3667], [Val_MSE: 0.0767], [Val_KL: 0.3650],
# EarlyStopping counter: 5 out of 10
# Epoch 25/1000: [MSE: 0.0759], [KL: 0.3664], [Val_MSE: 0.0715], [Val_KL: 0.3668],
# EarlyStopping counter: 6 out of 10
# Epoch 26/1000: [MSE: 0.0761], [KL: 0.3666], [Val_MSE: 0.0662], [Val_KL: 0.3690],
# Validation loss decreased (0.067406 --> 0.066166).  Saving model ...
# Epoch 27/1000: [MSE: 0.0750], [KL: 0.3665], [Val_MSE: 0.0691], [Val_KL: 0.3670],
# EarlyStopping counter: 1 out of 10
# Epoch 28/1000: [MSE: 0.0743], [KL: 0.3673], [Val_MSE: 0.0675], [Val_KL: 0.3710],
# EarlyStopping counter: 2 out of 10
# Epoch 29/1000: [MSE: 0.0742], [KL: 0.3668], [Val_MSE: 0.0667], [Val_KL: 0.3671],
# EarlyStopping counter: 3 out of 10
# Epoch 30/1000: [MSE: 0.0740], [KL: 0.3673], [Val_MSE: 0.0716], [Val_KL: 0.3671],
# EarlyStopping counter: 4 out of 10
# Epoch 31/1000: [MSE: 0.0725], [KL: 0.3666], [Val_MSE: 0.0639], [Val_KL: 0.3680],
# Validation loss decreased (0.066166 --> 0.063895).  Saving model ...
# Epoch 32/1000: [MSE: 0.0719], [KL: 0.3674], [Val_MSE: 0.0630], [Val_KL: 0.3683],
# Validation loss decreased (0.063895 --> 0.062993).  Saving model ...
# Epoch 33/1000: [MSE: 0.0699], [KL: 0.3672], [Val_MSE: 0.0658], [Val_KL: 0.3679],
# EarlyStopping counter: 1 out of 10
# Epoch 34/1000: [MSE: 0.0705], [KL: 0.3674], [Val_MSE: 0.0674], [Val_KL: 0.3671],
# EarlyStopping counter: 2 out of 10
# Epoch 35/1000: [MSE: 0.0717], [KL: 0.3672], [Val_MSE: 0.0625], [Val_KL: 0.3692],
# Validation loss decreased (0.062993 --> 0.062513).  Saving model ...
# Epoch 36/1000: [MSE: 0.0715], [KL: 0.3674], [Val_MSE: 0.0650], [Val_KL: 0.3679],
# EarlyStopping counter: 1 out of 10
# Epoch 37/1000: [MSE: 0.0694], [KL: 0.3674], [Val_MSE: 0.0664], [Val_KL: 0.3693],
# EarlyStopping counter: 2 out of 10
# Epoch 38/1000: [MSE: 0.0709], [KL: 0.3674], [Val_MSE: 0.0652], [Val_KL: 0.3684],
# EarlyStopping counter: 3 out of 10
# Epoch 39/1000: [MSE: 0.0687], [KL: 0.3671], [Val_MSE: 0.0614], [Val_KL: 0.3702],
# Validation loss decreased (0.062513 --> 0.061384).  Saving model ...
# Epoch 40/1000: [MSE: 0.0719], [KL: 0.3679], [Val_MSE: 0.0653], [Val_KL: 0.3696],
# EarlyStopping counter: 1 out of 10
# Epoch 41/1000: [MSE: 0.0719], [KL: 0.3668], [Val_MSE: 0.0668], [Val_KL: 0.3669],
# EarlyStopping counter: 2 out of 10
# Epoch 42/1000: [MSE: 0.0690], [KL: 0.3679], [Val_MSE: 0.0682], [Val_KL: 0.3696],
# EarlyStopping counter: 3 out of 10
# Epoch 43/1000: [MSE: 0.0706], [KL: 0.3676], [Val_MSE: 0.0682], [Val_KL: 0.3683],
# EarlyStopping counter: 4 out of 10
# Epoch 44/1000: [MSE: 0.0708], [KL: 0.3673], [Val_MSE: 0.0684], [Val_KL: 0.3664],
# EarlyStopping counter: 5 out of 10
# Epoch 45/1000: [MSE: 0.0696], [KL: 0.3675], [Val_MSE: 0.0659], [Val_KL: 0.3691],
# EarlyStopping counter: 6 out of 10
# Epoch 46/1000: [MSE: 0.0696], [KL: 0.3671], [Val_MSE: 0.0688], [Val_KL: 0.3664],
# EarlyStopping counter: 7 out of 10
# Epoch 47/1000: [MSE: 0.0672], [KL: 0.3674], [Val_MSE: 0.0607], [Val_KL: 0.3717],
# Validation loss decreased (0.061384 --> 0.060678).  Saving model ...
# Epoch 48/1000: [MSE: 0.0663], [KL: 0.3670], [Val_MSE: 0.0616], [Val_KL: 0.3686],
# EarlyStopping counter: 1 out of 10
# Epoch 49/1000: [MSE: 0.0671], [KL: 0.3673], [Val_MSE: 0.0630], [Val_KL: 0.3674],
# EarlyStopping counter: 2 out of 10
# Epoch 50/1000: [MSE: 0.0649], [KL: 0.3671], [Val_MSE: 0.0594], [Val_KL: 0.3686],
# Validation loss decreased (0.060678 --> 0.059419).  Saving model ...
# Epoch 51/1000: [MSE: 0.0661], [KL: 0.3676], [Val_MSE: 0.0602], [Val_KL: 0.3681],
# EarlyStopping counter: 1 out of 10
# Epoch 52/1000: [MSE: 0.0647], [KL: 0.3673], [Val_MSE: 0.0588], [Val_KL: 0.3692],
# Validation loss decreased (0.059419 --> 0.058770).  Saving model ...
# Epoch 53/1000: [MSE: 0.0658], [KL: 0.3673], [Val_MSE: 0.0595], [Val_KL: 0.3683],
# EarlyStopping counter: 1 out of 10
# Epoch 54/1000: [MSE: 0.0655], [KL: 0.3673], [Val_MSE: 0.0606], [Val_KL: 0.3679],
# EarlyStopping counter: 2 out of 10
# Epoch 55/1000: [MSE: 0.0659], [KL: 0.3674], [Val_MSE: 0.0591], [Val_KL: 0.3686],
# EarlyStopping counter: 3 out of 10
# Epoch 56/1000: [MSE: 0.0671], [KL: 0.3673], [Val_MSE: 0.0603], [Val_KL: 0.3687],
# EarlyStopping counter: 4 out of 10
# Epoch 57/1000: [MSE: 0.0657], [KL: 0.3673], [Val_MSE: 0.0602], [Val_KL: 0.3685],
# EarlyStopping counter: 5 out of 10
# Epoch 58/1000: [MSE: 0.0665], [KL: 0.3675], [Val_MSE: 0.0581], [Val_KL: 0.3696],
# Validation loss decreased (0.058770 --> 0.058109).  Saving model ...
# Epoch 59/1000: [MSE: 0.0668], [KL: 0.3672], [Val_MSE: 0.0602], [Val_KL: 0.3686],
# EarlyStopping counter: 1 out of 10
# Epoch 60/1000: [MSE: 0.0656], [KL: 0.3676], [Val_MSE: 0.0583], [Val_KL: 0.3693],
# EarlyStopping counter: 2 out of 10
# Epoch 61/1000: [MSE: 0.0667], [KL: 0.3675], [Val_MSE: 0.0587], [Val_KL: 0.3695],
# EarlyStopping counter: 3 out of 10
# Epoch 62/1000: [MSE: 0.0668], [KL: 0.3673], [Val_MSE: 0.0589], [Val_KL: 0.3683],
# EarlyStopping counter: 4 out of 10
# Epoch 63/1000: [MSE: 0.0642], [KL: 0.3671], [Val_MSE: 0.0597], [Val_KL: 0.3678],
# EarlyStopping counter: 5 out of 10
# Epoch 64/1000: [MSE: 0.0665], [KL: 0.3671], [Val_MSE: 0.0639], [Val_KL: 0.3668],
# EarlyStopping counter: 6 out of 10
# Epoch 65/1000: [MSE: 0.0649], [KL: 0.3675], [Val_MSE: 0.0622], [Val_KL: 0.3671],
# EarlyStopping counter: 7 out of 10
# Epoch 66/1000: [MSE: 0.0653], [KL: 0.3670], [Val_MSE: 0.0618], [Val_KL: 0.3670],
# EarlyStopping counter: 8 out of 10
# Epoch 67/1000: [MSE: 0.0654], [KL: 0.3674], [Val_MSE: 0.0618], [Val_KL: 0.3673],
# EarlyStopping counter: 9 out of 10
# Epoch 68/1000: [MSE: 0.0651], [KL: 0.3673], [Val_MSE: 0.0593], [Val_KL: 0.3689],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, kl, val_mse, val_kl):
    fig, axs = plt.subplots(1,2, figsize=(10,4))
    axs[0].plot(mse, color='r', label='Training')
    axs[0].plot(val_mse, color='b', label='Validation')
    axs[0].set_title('MSE Loss')
    axs[1].plot(kl, color='r', label='Training')
    axs[1].plot(val_kl, color='b', label='Validation')
    axs[1].set_title('KL Loss')
    plt.legend()
    #plt.savefig('./imgMix/mse-kl-mvae.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, kl, val_mse, val_kl)

# %%
vae.eval()
Z = torch.tensor(Z, dtype=torch.float32).to(device)
Z_enc = vae(Z)

# %%
idx = 1001
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z[idx,:].cpu().detach().numpy()), label='Original')
axs.plot(np.transpose(Z_enc[idx,:].cpu().detach().numpy()), label='Reconstructed')
axs.set_title('Original vs. Reconstructed Signals')
plt.legend()
plt.show()

# %%
vae.eval()
Z_latent = vae.encoder(Z)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(Z_latent.cpu().detach().numpy()))
axs[0].set_title('Latent Noisy Sensor Signal')
axs[1].plot(np.transpose(Z_enc.cpu().detach().numpy()))
axs[1].set_title('Recunstructed Noisy Sensor Signal')
axs[2].plot(np.transpose(Z.cpu().detach().numpy()))
axs[2].set_title('Original Noisy Sensor Signal')
plt.show()

# %% [markdown]
# **$t=101$ latent distribution**

# %%
vae.eval()
sample_size = 30
signal = Z[100:102]
signal_latent, signal_rec = [], []
for _ in range(sample_size):
    signal_rec.append(vae(signal))
    signal_latent.append(vae.encoder(signal))
signal_latent = torch.stack(signal_latent, dim=0)
signal_rec = torch.stack(signal_rec, dim=0)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(signal_latent.cpu().detach().numpy()[:,0,:]))
axs[0].set_title(r'Latent Sensor Signal for $t=101$')
axs[1].plot(np.transpose(signal_rec.cpu().detach().numpy()[:,0,:]))
axs[1].set_title(r'Recunstructed Sensor Signal for $t=101$')
axs[2].plot(np.transpose(signal.cpu().detach().numpy()[0]))
axs[2].set_title(r'Original Sensor Signal for $t=101$')
plt.show()

# %%
noise_type = 7
noise_percent = 0.5

# %%
import re
import os
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae_trainer import VAETrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')

# %%
seed = 37
torch.manual_seed(seed)

# %%
class SensorDataset():
    def __init__(self, data: np.array):
        self.x = self.np2tensor(data)
        
    @staticmethod
    def np2tensor(x):
        return torch.tensor(x, dtype=torch.float32)
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx]

# %%
latent_dims = 118
batch_size = 16
epochs = 1000

# %%
data_filename = 'data.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)
train_size = int(T * 0.8)
lr = 1e-1
scheduler = True
es_patience = 10

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Original Sensor Signal')
plt.show()

# %%
noise_size = int(T * noise_percent)
norm_operation_win = 50

# %%
# read attack noise
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... :   0%|          | 0/3 [00:00<?, ?it/s]
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  6.39it/s]

# %%
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for _type in noise_to_add_from:
    noise_id = random.sample(range(T), 1)
    noises.append(Z_noise[_type][noise_id])
random.shuffle(noises)
noises = np.concatenate(noises, axis=0)
# add noises to original sensor data Z
Z[noise_time] = noises

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Noisy Sensor Signal')
plt.show()

# %%
Z_train, Z_test = Z[:train_size], Z[train_size:]
training = SensorDataset(Z_train)
test = SensorDataset(Z_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = VAETrainer(latent_dim=latent_dims, lr=lr, 
                     lr_scheduler=scheduler, es_patience=es_patience,
                     checkpoint_name=f'vae_{int(noise_percent*100)}%.pt', 
                     seed=seed)
# Out:
# Device:  cpu

# %%
summary(trainer.vae, (1, 358))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [1, 358]                  --
# ├─VariationalEncoder: 1-1                [1, 118]                  --
# │    └─Linear: 2-1                       [1, 236]                  84,724
# │    └─BatchNorm1d: 2-2                  [1, 236]                  472
# │    └─Linear: 2-3                       [1, 118]                  27,966
# │    └─Linear: 2-4                       [1, 118]                  14,042
# │    └─Linear: 2-5                       [1, 118]                  14,042
# ├─Decoder: 1-2                           [1, 358]                  --
# │    └─Linear: 2-6                       [1, 236]                  28,084
# │    └─BatchNorm1d: 2-7                  [1, 236]                  472
# │    └─Linear: 2-8                       [1, 358]                  84,846
# ==========================================================================================
# Total params: 254,648
# Trainable params: 254,648
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.25
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ==========================================================================================

# %%
vae, mse, kl, val_mse, val_kl = trainer.train(train_dl, test_dl, epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 1.5550], [KL: 1.2617], [Val_MSE: 0.1144], [Val_KL: 0.3740],
# Validation loss decreased (inf --> 0.114407).  Saving model ...
# Epoch 2/1000: [MSE: 0.1234], [KL: 0.3762], [Val_MSE: 0.1299], [Val_KL: 0.3569],
# EarlyStopping counter: 1 out of 10
# Epoch 3/1000: [MSE: 0.1276], [KL: 0.3687], [Val_MSE: 0.1487], [Val_KL: 0.3663],
# EarlyStopping counter: 2 out of 10
# Epoch 4/1000: [MSE: 0.1196], [KL: 0.3639], [Val_MSE: 0.1332], [Val_KL: 0.3601],
# EarlyStopping counter: 3 out of 10
# Epoch 5/1000: [MSE: 0.1184], [KL: 0.3645], [Val_MSE: 0.0980], [Val_KL: 0.3855],
# Validation loss decreased (0.114407 --> 0.098024).  Saving model ...
# Epoch 6/1000: [MSE: 0.1251], [KL: 0.3628], [Val_MSE: 0.1209], [Val_KL: 0.3629],
# EarlyStopping counter: 1 out of 10
# Epoch 7/1000: [MSE: 0.1195], [KL: 0.3637], [Val_MSE: 0.1265], [Val_KL: 0.3569],
# EarlyStopping counter: 2 out of 10
# Epoch 8/1000: [MSE: 0.1144], [KL: 0.3631], [Val_MSE: 0.1172], [Val_KL: 0.3635],
# EarlyStopping counter: 3 out of 10
# Epoch 9/1000: [MSE: 0.1129], [KL: 0.3603], [Val_MSE: 0.0969], [Val_KL: 0.3686],
# Validation loss decreased (0.098024 --> 0.096898).  Saving model ...
# Epoch 10/1000: [MSE: 0.1077], [KL: 0.3598], [Val_MSE: 0.0968], [Val_KL: 0.3625],
# Validation loss decreased (0.096898 --> 0.096806).  Saving model ...
# Epoch 11/1000: [MSE: 0.1070], [KL: 0.3599], [Val_MSE: 0.1043], [Val_KL: 0.3608],
# EarlyStopping counter: 1 out of 10
# Epoch 12/1000: [MSE: 0.1090], [KL: 0.3592], [Val_MSE: 0.1023], [Val_KL: 0.3614],
# EarlyStopping counter: 2 out of 10
# Epoch 13/1000: [MSE: 0.1026], [KL: 0.3601], [Val_MSE: 0.0932], [Val_KL: 0.3634],
# Validation loss decreased (0.096806 --> 0.093243).  Saving model ...
# Epoch 14/1000: [MSE: 0.1015], [KL: 0.3594], [Val_MSE: 0.0906], [Val_KL: 0.3632],
# Validation loss decreased (0.093243 --> 0.090610).  Saving model ...
# Epoch 15/1000: [MSE: 0.1044], [KL: 0.3594], [Val_MSE: 0.0862], [Val_KL: 0.3622],
# Validation loss decreased (0.090610 --> 0.086208).  Saving model ...
# Epoch 16/1000: [MSE: 0.1018], [KL: 0.3593], [Val_MSE: 0.0886], [Val_KL: 0.3609],
# EarlyStopping counter: 1 out of 10
# Epoch 17/1000: [MSE: 0.1037], [KL: 0.3592], [Val_MSE: 0.1055], [Val_KL: 0.3612],
# EarlyStopping counter: 2 out of 10
# Epoch 18/1000: [MSE: 0.1003], [KL: 0.3592], [Val_MSE: 0.0906], [Val_KL: 0.3618],
# EarlyStopping counter: 3 out of 10
# Epoch 19/1000: [MSE: 0.1019], [KL: 0.3602], [Val_MSE: 0.1263], [Val_KL: 0.3722],
# EarlyStopping counter: 4 out of 10
# Epoch 20/1000: [MSE: 0.1014], [KL: 0.3592], [Val_MSE: 0.1084], [Val_KL: 0.3594],
# EarlyStopping counter: 5 out of 10
# Epoch 21/1000: [MSE: 0.1072], [KL: 0.3591], [Val_MSE: 0.0894], [Val_KL: 0.3614],
# EarlyStopping counter: 6 out of 10
# Epoch 22/1000: [MSE: 0.1010], [KL: 0.3591], [Val_MSE: 0.1167], [Val_KL: 0.3576],
# EarlyStopping counter: 7 out of 10
# Epoch 23/1000: [MSE: 0.0896], [KL: 0.3585], [Val_MSE: 0.0802], [Val_KL: 0.3591],
# Validation loss decreased (0.086208 --> 0.080153).  Saving model ...
# Epoch 24/1000: [MSE: 0.0867], [KL: 0.3588], [Val_MSE: 0.0796], [Val_KL: 0.3603],
# Validation loss decreased (0.080153 --> 0.079582).  Saving model ...
# Epoch 25/1000: [MSE: 0.0862], [KL: 0.3590], [Val_MSE: 0.0826], [Val_KL: 0.3586],
# EarlyStopping counter: 1 out of 10
# Epoch 26/1000: [MSE: 0.0863], [KL: 0.3589], [Val_MSE: 0.0795], [Val_KL: 0.3595],
# Validation loss decreased (0.079582 --> 0.079455).  Saving model ...
# Epoch 27/1000: [MSE: 0.0887], [KL: 0.3591], [Val_MSE: 0.0774], [Val_KL: 0.3601],
# Validation loss decreased (0.079455 --> 0.077400).  Saving model ...
# Epoch 28/1000: [MSE: 0.0853], [KL: 0.3591], [Val_MSE: 0.0774], [Val_KL: 0.3602],
# Validation loss decreased (0.077400 --> 0.077366).  Saving model ...
# Epoch 29/1000: [MSE: 0.0862], [KL: 0.3589], [Val_MSE: 0.0822], [Val_KL: 0.3598],
# EarlyStopping counter: 1 out of 10
# Epoch 30/1000: [MSE: 0.0863], [KL: 0.3588], [Val_MSE: 0.0851], [Val_KL: 0.3593],
# EarlyStopping counter: 2 out of 10
# Epoch 31/1000: [MSE: 0.0877], [KL: 0.3592], [Val_MSE: 0.0803], [Val_KL: 0.3595],
# EarlyStopping counter: 3 out of 10
# Epoch 32/1000: [MSE: 0.0860], [KL: 0.3593], [Val_MSE: 0.0772], [Val_KL: 0.3598],
# Validation loss decreased (0.077366 --> 0.077229).  Saving model ...
# Epoch 33/1000: [MSE: 0.0873], [KL: 0.3589], [Val_MSE: 0.0768], [Val_KL: 0.3603],
# Validation loss decreased (0.077229 --> 0.076804).  Saving model ...
# Epoch 34/1000: [MSE: 0.0855], [KL: 0.3594], [Val_MSE: 0.0806], [Val_KL: 0.3606],
# EarlyStopping counter: 1 out of 10
# Epoch 35/1000: [MSE: 0.0846], [KL: 0.3595], [Val_MSE: 0.0862], [Val_KL: 0.3600],
# EarlyStopping counter: 2 out of 10
# Epoch 36/1000: [MSE: 0.0862], [KL: 0.3595], [Val_MSE: 0.0781], [Val_KL: 0.3601],
# EarlyStopping counter: 3 out of 10
# Epoch 37/1000: [MSE: 0.0852], [KL: 0.3593], [Val_MSE: 0.0919], [Val_KL: 0.3589],
# EarlyStopping counter: 4 out of 10
# Epoch 38/1000: [MSE: 0.0846], [KL: 0.3590], [Val_MSE: 0.0752], [Val_KL: 0.3603],
# Validation loss decreased (0.076804 --> 0.075180).  Saving model ...
# Epoch 39/1000: [MSE: 0.0835], [KL: 0.3596], [Val_MSE: 0.0765], [Val_KL: 0.3613],
# EarlyStopping counter: 1 out of 10
# Epoch 40/1000: [MSE: 0.0856], [KL: 0.3601], [Val_MSE: 0.0780], [Val_KL: 0.3602],
# EarlyStopping counter: 2 out of 10
# Epoch 41/1000: [MSE: 0.0834], [KL: 0.3602], [Val_MSE: 0.0768], [Val_KL: 0.3598],
# EarlyStopping counter: 3 out of 10
# Epoch 42/1000: [MSE: 0.0831], [KL: 0.3604], [Val_MSE: 0.0729], [Val_KL: 0.3621],
# Validation loss decreased (0.075180 --> 0.072940).  Saving model ...
# Epoch 43/1000: [MSE: 0.0814], [KL: 0.3614], [Val_MSE: 0.0710], [Val_KL: 0.3648],
# Validation loss decreased (0.072940 --> 0.071032).  Saving model ...
# Epoch 44/1000: [MSE: 0.0807], [KL: 0.3618], [Val_MSE: 0.0708], [Val_KL: 0.3646],
# Validation loss decreased (0.071032 --> 0.070807).  Saving model ...
# Epoch 45/1000: [MSE: 0.0803], [KL: 0.3627], [Val_MSE: 0.0769], [Val_KL: 0.3605],
# EarlyStopping counter: 1 out of 10
# Epoch 46/1000: [MSE: 0.0772], [KL: 0.3633], [Val_MSE: 0.0701], [Val_KL: 0.3648],
# Validation loss decreased (0.070807 --> 0.070058).  Saving model ...
# Epoch 47/1000: [MSE: 0.0773], [KL: 0.3634], [Val_MSE: 0.0681], [Val_KL: 0.3672],
# Validation loss decreased (0.070058 --> 0.068077).  Saving model ...
# Epoch 48/1000: [MSE: 0.0740], [KL: 0.3638], [Val_MSE: 0.0692], [Val_KL: 0.3643],
# EarlyStopping counter: 1 out of 10
# Epoch 49/1000: [MSE: 0.0756], [KL: 0.3645], [Val_MSE: 0.0681], [Val_KL: 0.3658],
# EarlyStopping counter: 2 out of 10
# Epoch 50/1000: [MSE: 0.0741], [KL: 0.3643], [Val_MSE: 0.0677], [Val_KL: 0.3652],
# Validation loss decreased (0.068077 --> 0.067745).  Saving model ...
# Epoch 51/1000: [MSE: 0.0744], [KL: 0.3642], [Val_MSE: 0.0659], [Val_KL: 0.3645],
# Validation loss decreased (0.067745 --> 0.065945).  Saving model ...
# Epoch 52/1000: [MSE: 0.0754], [KL: 0.3642], [Val_MSE: 0.0689], [Val_KL: 0.3648],
# EarlyStopping counter: 1 out of 10
# Epoch 53/1000: [MSE: 0.0731], [KL: 0.3645], [Val_MSE: 0.0693], [Val_KL: 0.3648],
# EarlyStopping counter: 2 out of 10
# Epoch 54/1000: [MSE: 0.0754], [KL: 0.3640], [Val_MSE: 0.0628], [Val_KL: 0.3652],
# Validation loss decreased (0.065945 --> 0.062838).  Saving model ...
# Epoch 55/1000: [MSE: 0.0750], [KL: 0.3643], [Val_MSE: 0.0696], [Val_KL: 0.3633],
# EarlyStopping counter: 1 out of 10
# Epoch 56/1000: [MSE: 0.0705], [KL: 0.3646], [Val_MSE: 0.0659], [Val_KL: 0.3656],
# EarlyStopping counter: 2 out of 10
# Epoch 57/1000: [MSE: 0.0727], [KL: 0.3649], [Val_MSE: 0.0677], [Val_KL: 0.3677],
# EarlyStopping counter: 3 out of 10
# Epoch 58/1000: [MSE: 0.0723], [KL: 0.3643], [Val_MSE: 0.0671], [Val_KL: 0.3643],
# EarlyStopping counter: 4 out of 10
# Epoch 59/1000: [MSE: 0.0729], [KL: 0.3649], [Val_MSE: 0.0667], [Val_KL: 0.3652],
# EarlyStopping counter: 5 out of 10
# Epoch 60/1000: [MSE: 0.0713], [KL: 0.3651], [Val_MSE: 0.0627], [Val_KL: 0.3661],
# Validation loss decreased (0.062838 --> 0.062721).  Saving model ...
# Epoch 61/1000: [MSE: 0.0708], [KL: 0.3650], [Val_MSE: 0.0697], [Val_KL: 0.3647],
# EarlyStopping counter: 1 out of 10
# Epoch 62/1000: [MSE: 0.0723], [KL: 0.3649], [Val_MSE: 0.0637], [Val_KL: 0.3659],
# EarlyStopping counter: 2 out of 10
# Epoch 63/1000: [MSE: 0.0702], [KL: 0.3652], [Val_MSE: 0.0607], [Val_KL: 0.3668],
# Validation loss decreased (0.062721 --> 0.060705).  Saving model ...
# Epoch 64/1000: [MSE: 0.0706], [KL: 0.3653], [Val_MSE: 0.0621], [Val_KL: 0.3670],
# EarlyStopping counter: 1 out of 10
# Epoch 65/1000: [MSE: 0.0716], [KL: 0.3654], [Val_MSE: 0.0639], [Val_KL: 0.3657],
# EarlyStopping counter: 2 out of 10
# Epoch 66/1000: [MSE: 0.0701], [KL: 0.3650], [Val_MSE: 0.0614], [Val_KL: 0.3658],
# EarlyStopping counter: 3 out of 10
# Epoch 67/1000: [MSE: 0.0708], [KL: 0.3656], [Val_MSE: 0.0612], [Val_KL: 0.3657],
# EarlyStopping counter: 4 out of 10
# Epoch 68/1000: [MSE: 0.0719], [KL: 0.3653], [Val_MSE: 0.0582], [Val_KL: 0.3692],
# Validation loss decreased (0.060705 --> 0.058155).  Saving model ...
# Epoch 69/1000: [MSE: 0.0726], [KL: 0.3655], [Val_MSE: 0.0652], [Val_KL: 0.3666],
# EarlyStopping counter: 1 out of 10
# Epoch 70/1000: [MSE: 0.0694], [KL: 0.3649], [Val_MSE: 0.0623], [Val_KL: 0.3655],
# EarlyStopping counter: 2 out of 10
# Epoch 71/1000: [MSE: 0.0698], [KL: 0.3653], [Val_MSE: 0.0730], [Val_KL: 0.3661],
# EarlyStopping counter: 3 out of 10
# Epoch 72/1000: [MSE: 0.0699], [KL: 0.3650], [Val_MSE: 0.0856], [Val_KL: 0.3654],
# EarlyStopping counter: 4 out of 10
# Epoch 73/1000: [MSE: 0.0699], [KL: 0.3653], [Val_MSE: 0.0642], [Val_KL: 0.3656],
# EarlyStopping counter: 5 out of 10
# Epoch 74/1000: [MSE: 0.0688], [KL: 0.3652], [Val_MSE: 0.0659], [Val_KL: 0.3668],
# EarlyStopping counter: 6 out of 10
# Epoch 75/1000: [MSE: 0.0717], [KL: 0.3657], [Val_MSE: 0.0596], [Val_KL: 0.3669],
# EarlyStopping counter: 7 out of 10
# Epoch 76/1000: [MSE: 0.0675], [KL: 0.3656], [Val_MSE: 0.0583], [Val_KL: 0.3659],
# EarlyStopping counter: 8 out of 10
# Epoch 77/1000: [MSE: 0.0671], [KL: 0.3652], [Val_MSE: 0.0612], [Val_KL: 0.3652],
# EarlyStopping counter: 9 out of 10
# Epoch 78/1000: [MSE: 0.0664], [KL: 0.3655], [Val_MSE: 0.0577], [Val_KL: 0.3668],
# Validation loss decreased (0.058155 --> 0.057654).  Saving model ...
# Epoch 79/1000: [MSE: 0.0649], [KL: 0.3654], [Val_MSE: 0.0565], [Val_KL: 0.3666],
# Validation loss decreased (0.057654 --> 0.056505).  Saving model ...
# Epoch 80/1000: [MSE: 0.0671], [KL: 0.3657], [Val_MSE: 0.0615], [Val_KL: 0.3649],
# EarlyStopping counter: 1 out of 10
# Epoch 81/1000: [MSE: 0.0663], [KL: 0.3656], [Val_MSE: 0.0589], [Val_KL: 0.3656],
# EarlyStopping counter: 2 out of 10
# Epoch 82/1000: [MSE: 0.0677], [KL: 0.3656], [Val_MSE: 0.0670], [Val_KL: 0.3648],
# EarlyStopping counter: 3 out of 10
# Epoch 83/1000: [MSE: 0.0653], [KL: 0.3660], [Val_MSE: 0.0629], [Val_KL: 0.3646],
# EarlyStopping counter: 4 out of 10
# Epoch 84/1000: [MSE: 0.0651], [KL: 0.3656], [Val_MSE: 0.0587], [Val_KL: 0.3671],
# EarlyStopping counter: 5 out of 10
# Epoch 85/1000: [MSE: 0.0667], [KL: 0.3657], [Val_MSE: 0.0586], [Val_KL: 0.3667],
# EarlyStopping counter: 6 out of 10
# Epoch 86/1000: [MSE: 0.0653], [KL: 0.3657], [Val_MSE: 0.0659], [Val_KL: 0.3648],
# EarlyStopping counter: 7 out of 10
# Epoch 87/1000: [MSE: 0.0640], [KL: 0.3651], [Val_MSE: 0.0621], [Val_KL: 0.3653],
# EarlyStopping counter: 8 out of 10
# Epoch 88/1000: [MSE: 0.0648], [KL: 0.3654], [Val_MSE: 0.0612], [Val_KL: 0.3657],
# EarlyStopping counter: 9 out of 10
# Epoch 89/1000: [MSE: 0.0642], [KL: 0.3652], [Val_MSE: 0.0581], [Val_KL: 0.3653],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, kl, val_mse, val_kl):
    fig, axs = plt.subplots(2, figsize=(8,12))
    axs[0].plot(mse, color='r', label='Training')
    axs[0].plot(val_mse, color='b', label='Validation')
    axs[0].set_title('MSE Loss')
    axs[1].plot(kl, color='r', label='Training')
    axs[1].plot(val_kl, color='b', label='Validation')
    axs[1].set_title('KL Loss')
    plt.legend()
    #plt.savefig('./imgMix/mse-kl-mvae.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, kl, val_mse, val_kl)

# %%
vae.eval()
Z = torch.tensor(Z, dtype=torch.float32)
Z_enc = vae(Z)

# %%
idx = 1001
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z[idx,:].cpu().detach().numpy()), label='Original')
axs.plot(np.transpose(Z_enc[idx,:].cpu().detach().numpy()), label='Reconstructed')
axs.set_title('Original vs. Reconstructed Signals')
plt.legend()
plt.show()

# %%
vae.eval()
Z_latent = vae.encoder(Z)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(Z_latent.cpu().detach().numpy()))
axs[0].set_title('Latent Noisy Sensor Signal')
axs[1].plot(np.transpose(Z_enc.cpu().detach().numpy()))
axs[1].set_title('Recunstructed Noisy Sensor Signal')
axs[2].plot(np.transpose(Z.cpu().detach().numpy()))
axs[2].set_title('Original Noisy Sensor Signal')
plt.show()

# %% [markdown]
# **$t=1$ latent distribution**

# %%
vae.eval()
sample_size = 30
signal = Z[0:2]
signal_latent, signal_rec = [], []
for _ in range(sample_size):
    signal_rec.append(vae(signal))
    signal_latent.append(vae.encoder(signal))
signal_latent = torch.stack(signal_latent, dim=0)
signal_rec = torch.stack(signal_rec, dim=0)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(signal_latent.cpu().detach().numpy()[:,0,:]))
axs[0].set_title(r'Latent Noisy Sensor Signal for $t=1$')
axs[1].plot(np.transpose(signal_rec.cpu().detach().numpy()[:,0,:]))
axs[1].set_title(r'Recunstructed Noisy Sensor Signal for $t=1$')
axs[2].plot(np.transpose(signal.cpu().detach().numpy()[0]))
axs[2].set_title(r'Original Noisy Sensor Signal for $t=1$')
plt.show()

# %%
noise_type = 7
noise_percent = 0.50

# %%
import os
import re
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt
from pandas import DataFrame, concat

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae import VAE
from models.rnn_trainer import RNNTrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')
# Path to the folder where the pretrained models are saved
CHECKPOINT_PATH = os.path.join(os.getcwd(), 'checkpoints')

# %%
seed = 13
# seed = 23
torch.manual_seed(seed)
# torch.cuda.manual_seed(seed)
# torch.cuda.manual_seed_all(seed)
# torch.backends.cudnn.deterministic = True
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class RNNDataset():
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
latent_dim = 118
hidden_size = 100
num_layers = 2
batch_size = 16
rnn_window = 10
epochs = 1000
lr = 1e-1
scheduler = True
es_patience = 10

# %%
data_filename = 'Normal1.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)

# %%
vae = VAE(latent_dim).to(device)
vae.load_state_dict(torch.load(os.path.join(CHECKPOINT_PATH, f'vae_{int(noise_percent*100)}%.pt')))
# Out:
# <All keys matched successfully>

# %%
# read attack noise
noise_size = int(T * noise_percent)
norm_operation_win = 50
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  7.06it/s]

# %%
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for typ in noise_to_add_from:
    noise_id = random.sample(range(T), 1)
    noises.append(Z_noise[typ][noise_id])
random.shuffle(noises)
noises = np.concatenate(noises, axis=0)
# add noises to original sensor data Z
Z[noise_time] = noises
Z = torch.tensor(Z, dtype=torch.float32).to(device)

# %%
vae.eval()
Z_enc = vae.encoder(Z)
Z_supervised = series_to_supervised(Z_enc.cpu().detach().numpy(), n_in=rnn_window)
Z_supervised = Z_supervised.values
X, y = Z_supervised[:,:rnn_window * latent_dim], Z_supervised[:, rnn_window * latent_dim:]
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]
training = RNNDataset(X_train, y_train)
test = RNNDataset(X_test, y_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = RNNTrainer(input_dim=rnn_window * latent_dim, 
                     outputdims = latent_dim,
                     hidden_dim=hidden_size,
                     num_layers=num_layers,
                     lr=lr,
                     lr_scheduler=scheduler,
                     es_patience=es_patience,
                     checkpoint_name=f'rnn_{int(noise_percent*100)}%.pt',
                     seed=13)
# Out:
# Device:  cpu

# %%
summary(trainer.rnn, (1, rnn_window * latent_dim))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# RNN                                      [1, 118]                  --
# ├─LSTM: 1-1                              [1, 50]                   543,600
# ├─Linear: 1-2                            [1, 118]                  6,018
# ==========================================================================================
# Total params: 549,618
# Trainable params: 549,618
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 27.19
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 2.20
# Estimated Total Size (MB): 2.20
# ==========================================================================================

# %%
rnn, mse, val_mse = trainer.train(train_dl=train_dl,
                                  test_dl=test_dl,
                                  epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 34.2204], [Val_MSE: 44.2739],
# Validation loss decreased (inf --> 44.273870).  Saving model ...
# Epoch 2/1000: [MSE: 123.4768], [Val_MSE: 114.7354],
# EarlyStopping counter: 1 out of 10
# Epoch 3/1000: [MSE: 34.5838], [Val_MSE: 2.5877],
# Validation loss decreased (44.273870 --> 2.587659).  Saving model ...
# Epoch 4/1000: [MSE: 2.9286], [Val_MSE: 4.6345],
# EarlyStopping counter: 1 out of 10
# Epoch 5/1000: [MSE: 5.9581], [Val_MSE: 14.2336],
# EarlyStopping counter: 2 out of 10
# Epoch 6/1000: [MSE: 151.3888], [Val_MSE: 832.7694],
# EarlyStopping counter: 3 out of 10
# Epoch 7/1000: [MSE: 260.6110], [Val_MSE: 68.9480],
# EarlyStopping counter: 4 out of 10
# Epoch 8/1000: [MSE: 39.5433], [Val_MSE: 20.7818],
# EarlyStopping counter: 5 out of 10
# Epoch 9/1000: [MSE: 9.3324], [Val_MSE: 7.0815],
# EarlyStopping counter: 6 out of 10
# Epoch 10/1000: [MSE: 19.4198], [Val_MSE: 33.8991],
# EarlyStopping counter: 7 out of 10
# Epoch 11/1000: [MSE: 3.8345], [Val_MSE: 0.7994],
# Validation loss decreased (2.587659 --> 0.799369).  Saving model ...
# Epoch 12/1000: [MSE: 0.7256], [Val_MSE: 0.6942],
# Validation loss decreased (0.799369 --> 0.694204).  Saving model ...
# Epoch 13/1000: [MSE: 0.6657], [Val_MSE: 0.6579],
# Validation loss decreased (0.694204 --> 0.657866).  Saving model ...
# Epoch 14/1000: [MSE: 0.6568], [Val_MSE: 0.6399],
# Validation loss decreased (0.657866 --> 0.639900).  Saving model ...
# Epoch 15/1000: [MSE: 0.6645], [Val_MSE: 0.6823],
# EarlyStopping counter: 1 out of 10
# Epoch 16/1000: [MSE: 0.6918], [Val_MSE: 0.6889],
# EarlyStopping counter: 2 out of 10
# Epoch 17/1000: [MSE: 0.7233], [Val_MSE: 0.6612],
# EarlyStopping counter: 3 out of 10
# Epoch 18/1000: [MSE: 0.7587], [Val_MSE: 0.6748],
# EarlyStopping counter: 4 out of 10
# Epoch 19/1000: [MSE: 0.7664], [Val_MSE: 0.8898],
# EarlyStopping counter: 5 out of 10
# Epoch 20/1000: [MSE: 0.8200], [Val_MSE: 0.7487],
# EarlyStopping counter: 6 out of 10
# Epoch 21/1000: [MSE: 0.8942], [Val_MSE: 1.1202],
# EarlyStopping counter: 7 out of 10
# Epoch 22/1000: [MSE: 0.5930], [Val_MSE: 0.5428],
# Validation loss decreased (0.639900 --> 0.542811).  Saving model ...
# Epoch 23/1000: [MSE: 0.5477], [Val_MSE: 0.5461],
# EarlyStopping counter: 1 out of 10
# Epoch 24/1000: [MSE: 0.5502], [Val_MSE: 0.5482],
# EarlyStopping counter: 2 out of 10
# Epoch 25/1000: [MSE: 0.5556], [Val_MSE: 0.5481],
# EarlyStopping counter: 3 out of 10
# Epoch 26/1000: [MSE: 0.5629], [Val_MSE: 0.5577],
# EarlyStopping counter: 4 out of 10
# Epoch 27/1000: [MSE: 0.5681], [Val_MSE: 0.5520],
# EarlyStopping counter: 5 out of 10
# Epoch 28/1000: [MSE: 0.5754], [Val_MSE: 0.5738],
# EarlyStopping counter: 6 out of 10
# Epoch 29/1000: [MSE: 0.5799], [Val_MSE: 0.5727],
# EarlyStopping counter: 7 out of 10
# Epoch 30/1000: [MSE: 0.5234], [Val_MSE: 0.5182],
# Validation loss decreased (0.542811 --> 0.518171).  Saving model ...
# Epoch 31/1000: [MSE: 0.5180], [Val_MSE: 0.5155],
# Validation loss decreased (0.518171 --> 0.515504).  Saving model ...
# Epoch 32/1000: [MSE: 0.5187], [Val_MSE: 0.5199],
# EarlyStopping counter: 1 out of 10
# Epoch 33/1000: [MSE: 0.5193], [Val_MSE: 0.5174],
# EarlyStopping counter: 2 out of 10
# Epoch 34/1000: [MSE: 0.5217], [Val_MSE: 0.5194],
# EarlyStopping counter: 3 out of 10
# Epoch 35/1000: [MSE: 0.5219], [Val_MSE: 0.5247],
# EarlyStopping counter: 4 out of 10
# Epoch 36/1000: [MSE: 0.5246], [Val_MSE: 0.5206],
# EarlyStopping counter: 5 out of 10
# Epoch 37/1000: [MSE: 0.5255], [Val_MSE: 0.5241],
# EarlyStopping counter: 6 out of 10
# Epoch 38/1000: [MSE: 0.5273], [Val_MSE: 0.5284],
# EarlyStopping counter: 7 out of 10
# Epoch 39/1000: [MSE: 0.5107], [Val_MSE: 0.5090],
# Validation loss decreased (0.515504 --> 0.508979).  Saving model ...
# Epoch 40/1000: [MSE: 0.5082], [Val_MSE: 0.5078],
# Validation loss decreased (0.508979 --> 0.507784).  Saving model ...
# Epoch 41/1000: [MSE: 0.5077], [Val_MSE: 0.5081],
# EarlyStopping counter: 1 out of 10
# Epoch 42/1000: [MSE: 0.5077], [Val_MSE: 0.5084],
# EarlyStopping counter: 2 out of 10
# Epoch 43/1000: [MSE: 0.5079], [Val_MSE: 0.5096],
# EarlyStopping counter: 3 out of 10
# Epoch 44/1000: [MSE: 0.5083], [Val_MSE: 0.5085],
# EarlyStopping counter: 4 out of 10
# Epoch 45/1000: [MSE: 0.5088], [Val_MSE: 0.5082],
# EarlyStopping counter: 5 out of 10
# Epoch 46/1000: [MSE: 0.5088], [Val_MSE: 0.5098],
# EarlyStopping counter: 6 out of 10
# Epoch 47/1000: [MSE: 0.5094], [Val_MSE: 0.5099],
# EarlyStopping counter: 7 out of 10
# Epoch 48/1000: [MSE: 0.5055], [Val_MSE: 0.5059],
# Validation loss decreased (0.507784 --> 0.505871).  Saving model ...
# Epoch 49/1000: [MSE: 0.5044], [Val_MSE: 0.5060],
# EarlyStopping counter: 1 out of 10
# Epoch 50/1000: [MSE: 0.5042], [Val_MSE: 0.5049],
# Validation loss decreased (0.505871 --> 0.504888).  Saving model ...
# Epoch 51/1000: [MSE: 0.5043], [Val_MSE: 0.5059],
# EarlyStopping counter: 1 out of 10
# Epoch 52/1000: [MSE: 0.5045], [Val_MSE: 0.5056],
# EarlyStopping counter: 2 out of 10
# Epoch 53/1000: [MSE: 0.5044], [Val_MSE: 0.5054],
# EarlyStopping counter: 3 out of 10
# Epoch 54/1000: [MSE: 0.5044], [Val_MSE: 0.5051],
# EarlyStopping counter: 4 out of 10
# Epoch 55/1000: [MSE: 0.5047], [Val_MSE: 0.5057],
# EarlyStopping counter: 5 out of 10
# Epoch 56/1000: [MSE: 0.5045], [Val_MSE: 0.5057],
# EarlyStopping counter: 6 out of 10
# Epoch 57/1000: [MSE: 0.5046], [Val_MSE: 0.5057],
# EarlyStopping counter: 7 out of 10
# Epoch 58/1000: [MSE: 0.5047], [Val_MSE: 0.5059],
# EarlyStopping counter: 8 out of 10
# Epoch 59/1000: [MSE: 0.5046], [Val_MSE: 0.5062],
# EarlyStopping counter: 9 out of 10
# Epoch 60/1000: [MSE: 0.5047], [Val_MSE: 0.5054],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, val_mse):
    fig, axs = plt.subplots(figsize=(8,4))
    axs.plot(mse, color='r', label='Training')
    axs.plot(val_mse, color='b', label='Validation')
    axs.set_title('MSE vs. Validation MSE')
    plt.legend()
    # plt.savefig('./img/mrnntraining.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, val_mse)

# %%
zz0 = torch.tensor(X_test[-3:-1,:], dtype=torch.float32).to(device)
rnn.eval()
zz = rnn(zz0)
s_rec = vae.decoder(zz)

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z.cpu().detach().numpy()[-1,:]), label='True')
axs.plot(np.transpose(s_rec[0,:].cpu().detach().numpy()), label='Prediction')
axs.set_title('Original Signals')
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(s_rec.cpu().detach().numpy()))
axs.set_title('Next Step Signals')
plt.show()

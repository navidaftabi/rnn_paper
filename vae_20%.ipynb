# %%
noise_type = 7
noise_percent = 0.2

# %%
import re
import os
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae_trainer import VAETrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')

# %%
seed = 37
torch.manual_seed(seed)

# %%
class SensorDataset():
    def __init__(self, data: np.array):
        self.x = self.np2tensor(data)
        
    @staticmethod
    def np2tensor(x):
        return torch.tensor(x, dtype=torch.float32)
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx]

# %%
latent_dims = 118
batch_size = 16
epochs = 1000

# %%
data_filename = 'data.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)
train_size = int(T * 0.8)
lr = 1e-1
scheduler = True
es_patience = 10

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Original Sensor Signal')
plt.show()

# %%
noise_size = int(T * noise_percent)
norm_operation_win = 50

# %%
# read attack noise
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  7.00it/s]

# %%
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for type in noise_to_add_from:
    noise_id = random.sample(range(T), 1)
    noises.append(Z_noise[type][noise_id])
random.shuffle(noises)
noises = np.concatenate(noises, axis=0)
# add noises to original sensor data Z
Z[noise_time] = noises

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Noisy Sensor Signal')
plt.show()

# %%
Z_train, Z_test = Z[:train_size], Z[train_size:]
training = SensorDataset(Z_train)
test = SensorDataset(Z_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = VAETrainer(latent_dim=latent_dims, lr=lr, 
                     lr_scheduler=scheduler, es_patience=es_patience,
                     checkpoint_name='vae_20%.pt', seed=seed)
# Out:
# Device:  cpu

# %%
summary(trainer.vae, (1, 358))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [1, 358]                  --
# ├─VariationalEncoder: 1-1                [1, 118]                  --
# │    └─Linear: 2-1                       [1, 236]                  84,724
# │    └─BatchNorm1d: 2-2                  [1, 236]                  472
# │    └─Linear: 2-3                       [1, 118]                  27,966
# │    └─Linear: 2-4                       [1, 118]                  14,042
# │    └─Linear: 2-5                       [1, 118]                  14,042
# ├─Decoder: 1-2                           [1, 358]                  --
# │    └─Linear: 2-6                       [1, 236]                  28,084
# │    └─BatchNorm1d: 2-7                  [1, 236]                  472
# │    └─Linear: 2-8                       [1, 358]                  84,846
# ==========================================================================================
# Total params: 254,648
# Trainable params: 254,648
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.25
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ==========================================================================================

# %%
vae, mse, kl, val_mse, val_kl = trainer.train(train_dl, test_dl, epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 1.7808], [KL: 1.1158], [Val_MSE: 0.1478], [Val_KL: 0.3685],
# Validation loss decreased (inf --> 0.147775).  Saving model ...
# Epoch 2/1000: [MSE: 0.1180], [KL: 0.3689], [Val_MSE: 0.1592], [Val_KL: 0.3663],
# EarlyStopping counter: 1 out of 10
# Epoch 3/1000: [MSE: 0.1152], [KL: 0.3670], [Val_MSE: 0.1200], [Val_KL: 0.3648],
# Validation loss decreased (0.147775 --> 0.119992).  Saving model ...
# Epoch 4/1000: [MSE: 0.1106], [KL: 0.3637], [Val_MSE: 0.0956], [Val_KL: 0.3621],
# Validation loss decreased (0.119992 --> 0.095627).  Saving model ...
# Epoch 5/1000: [MSE: 0.1071], [KL: 0.3626], [Val_MSE: 0.1229], [Val_KL: 0.3606],
# EarlyStopping counter: 1 out of 10
# Epoch 6/1000: [MSE: 0.1036], [KL: 0.3606], [Val_MSE: 0.1280], [Val_KL: 0.3648],
# EarlyStopping counter: 2 out of 10
# Epoch 7/1000: [MSE: 0.1031], [KL: 0.3603], [Val_MSE: 0.1016], [Val_KL: 0.3594],
# EarlyStopping counter: 3 out of 10
# Epoch 8/1000: [MSE: 0.1049], [KL: 0.3604], [Val_MSE: 0.1050], [Val_KL: 0.3596],
# EarlyStopping counter: 4 out of 10
# Epoch 9/1000: [MSE: 0.1062], [KL: 0.3607], [Val_MSE: 0.0980], [Val_KL: 0.3657],
# EarlyStopping counter: 5 out of 10
# Epoch 10/1000: [MSE: 0.1017], [KL: 0.3604], [Val_MSE: 0.0906], [Val_KL: 0.3645],
# Validation loss decreased (0.095627 --> 0.090561).  Saving model ...
# Epoch 11/1000: [MSE: 0.1054], [KL: 0.3605], [Val_MSE: 0.0936], [Val_KL: 0.3608],
# EarlyStopping counter: 1 out of 10
# Epoch 12/1000: [MSE: 0.1106], [KL: 0.3602], [Val_MSE: 0.1149], [Val_KL: 0.3588],
# EarlyStopping counter: 2 out of 10
# Epoch 13/1000: [MSE: 0.1071], [KL: 0.3605], [Val_MSE: 0.0935], [Val_KL: 0.3628],
# EarlyStopping counter: 3 out of 10
# Epoch 14/1000: [MSE: 0.1074], [KL: 0.3600], [Val_MSE: 0.1036], [Val_KL: 0.3610],
# EarlyStopping counter: 4 out of 10
# Epoch 15/1000: [MSE: 0.1088], [KL: 0.3601], [Val_MSE: 0.0865], [Val_KL: 0.3622],
# Validation loss decreased (0.090561 --> 0.086517).  Saving model ...
# Epoch 16/1000: [MSE: 0.1013], [KL: 0.3604], [Val_MSE: 0.1004], [Val_KL: 0.3588],
# EarlyStopping counter: 1 out of 10
# Epoch 17/1000: [MSE: 0.1007], [KL: 0.3605], [Val_MSE: 0.1028], [Val_KL: 0.3644],
# EarlyStopping counter: 2 out of 10
# Epoch 18/1000: [MSE: 0.1067], [KL: 0.3604], [Val_MSE: 0.1097], [Val_KL: 0.3613],
# EarlyStopping counter: 3 out of 10
# Epoch 19/1000: [MSE: 0.1053], [KL: 0.3608], [Val_MSE: 0.1208], [Val_KL: 0.3593],
# EarlyStopping counter: 4 out of 10
# Epoch 20/1000: [MSE: 0.1063], [KL: 0.3601], [Val_MSE: 0.1129], [Val_KL: 0.3611],
# EarlyStopping counter: 5 out of 10
# Epoch 21/1000: [MSE: 0.1038], [KL: 0.3609], [Val_MSE: 0.1170], [Val_KL: 0.3595],
# EarlyStopping counter: 6 out of 10
# Epoch 22/1000: [MSE: 0.1057], [KL: 0.3606], [Val_MSE: 0.1134], [Val_KL: 0.3607],
# EarlyStopping counter: 7 out of 10
# Epoch 23/1000: [MSE: 0.0929], [KL: 0.3592], [Val_MSE: 0.0862], [Val_KL: 0.3611],
# Validation loss decreased (0.086517 --> 0.086199).  Saving model ...
# Epoch 24/1000: [MSE: 0.0911], [KL: 0.3599], [Val_MSE: 0.0833], [Val_KL: 0.3614],
# Validation loss decreased (0.086199 --> 0.083320).  Saving model ...
# Epoch 25/1000: [MSE: 0.0904], [KL: 0.3598], [Val_MSE: 0.0860], [Val_KL: 0.3608],
# EarlyStopping counter: 1 out of 10
# Epoch 26/1000: [MSE: 0.0922], [KL: 0.3596], [Val_MSE: 0.0897], [Val_KL: 0.3608],
# EarlyStopping counter: 2 out of 10
# Epoch 27/1000: [MSE: 0.0937], [KL: 0.3597], [Val_MSE: 0.0877], [Val_KL: 0.3604],
# EarlyStopping counter: 3 out of 10
# Epoch 28/1000: [MSE: 0.0915], [KL: 0.3601], [Val_MSE: 0.0836], [Val_KL: 0.3613],
# EarlyStopping counter: 4 out of 10
# Epoch 29/1000: [MSE: 0.0918], [KL: 0.3597], [Val_MSE: 0.0854], [Val_KL: 0.3614],
# EarlyStopping counter: 5 out of 10
# Epoch 30/1000: [MSE: 0.0928], [KL: 0.3595], [Val_MSE: 0.0826], [Val_KL: 0.3610],
# Validation loss decreased (0.083320 --> 0.082567).  Saving model ...
# Epoch 31/1000: [MSE: 0.0945], [KL: 0.3595], [Val_MSE: 0.0861], [Val_KL: 0.3607],
# EarlyStopping counter: 1 out of 10
# Epoch 32/1000: [MSE: 0.0922], [KL: 0.3598], [Val_MSE: 0.0855], [Val_KL: 0.3609],
# EarlyStopping counter: 2 out of 10
# Epoch 33/1000: [MSE: 0.0971], [KL: 0.3595], [Val_MSE: 0.0858], [Val_KL: 0.3615],
# EarlyStopping counter: 3 out of 10
# Epoch 34/1000: [MSE: 0.0956], [KL: 0.3596], [Val_MSE: 0.0874], [Val_KL: 0.3617],
# EarlyStopping counter: 4 out of 10
# Epoch 35/1000: [MSE: 0.0934], [KL: 0.3596], [Val_MSE: 0.0864], [Val_KL: 0.3613],
# EarlyStopping counter: 5 out of 10
# Epoch 36/1000: [MSE: 0.0917], [KL: 0.3597], [Val_MSE: 0.0822], [Val_KL: 0.3615],
# Validation loss decreased (0.082567 --> 0.082194).  Saving model ...
# Epoch 37/1000: [MSE: 0.0960], [KL: 0.3599], [Val_MSE: 0.0859], [Val_KL: 0.3616],
# EarlyStopping counter: 1 out of 10
# Epoch 38/1000: [MSE: 0.0922], [KL: 0.3597], [Val_MSE: 0.0859], [Val_KL: 0.3604],
# EarlyStopping counter: 2 out of 10
# Epoch 39/1000: [MSE: 0.0891], [KL: 0.3600], [Val_MSE: 0.0899], [Val_KL: 0.3605],
# EarlyStopping counter: 3 out of 10
# Epoch 40/1000: [MSE: 0.0923], [KL: 0.3597], [Val_MSE: 0.0818], [Val_KL: 0.3622],
# Validation loss decreased (0.082194 --> 0.081829).  Saving model ...
# Epoch 41/1000: [MSE: 0.0943], [KL: 0.3595], [Val_MSE: 0.0857], [Val_KL: 0.3604],
# EarlyStopping counter: 1 out of 10
# Epoch 42/1000: [MSE: 0.0929], [KL: 0.3597], [Val_MSE: 0.0880], [Val_KL: 0.3601],
# EarlyStopping counter: 2 out of 10
# Epoch 43/1000: [MSE: 0.0926], [KL: 0.3597], [Val_MSE: 0.0891], [Val_KL: 0.3608],
# EarlyStopping counter: 3 out of 10
# Epoch 44/1000: [MSE: 0.0969], [KL: 0.3597], [Val_MSE: 0.0838], [Val_KL: 0.3622],
# EarlyStopping counter: 4 out of 10
# Epoch 45/1000: [MSE: 0.0918], [KL: 0.3596], [Val_MSE: 0.0835], [Val_KL: 0.3618],
# EarlyStopping counter: 5 out of 10
# Epoch 46/1000: [MSE: 0.0913], [KL: 0.3596], [Val_MSE: 0.0904], [Val_KL: 0.3601],
# EarlyStopping counter: 6 out of 10
# Epoch 47/1000: [MSE: 0.0918], [KL: 0.3598], [Val_MSE: 0.0885], [Val_KL: 0.3608],
# EarlyStopping counter: 7 out of 10
# Epoch 48/1000: [MSE: 0.0904], [KL: 0.3592], [Val_MSE: 0.0870], [Val_KL: 0.3602],
# EarlyStopping counter: 8 out of 10
# Epoch 49/1000: [MSE: 0.0900], [KL: 0.3595], [Val_MSE: 0.0817], [Val_KL: 0.3610],
# Validation loss decreased (0.081829 --> 0.081671).  Saving model ...
# Epoch 50/1000: [MSE: 0.0898], [KL: 0.3596], [Val_MSE: 0.0838], [Val_KL: 0.3607],
# EarlyStopping counter: 1 out of 10
# Epoch 51/1000: [MSE: 0.0935], [KL: 0.3597], [Val_MSE: 0.0815], [Val_KL: 0.3620],
# Validation loss decreased (0.081671 --> 0.081467).  Saving model ...
# Epoch 52/1000: [MSE: 0.0917], [KL: 0.3594], [Val_MSE: 0.0810], [Val_KL: 0.3613],
# Validation loss decreased (0.081467 --> 0.080972).  Saving model ...
# Epoch 53/1000: [MSE: 0.0931], [KL: 0.3595], [Val_MSE: 0.0819], [Val_KL: 0.3609],
# EarlyStopping counter: 1 out of 10
# Epoch 54/1000: [MSE: 0.0908], [KL: 0.3593], [Val_MSE: 0.0839], [Val_KL: 0.3603],
# EarlyStopping counter: 2 out of 10
# Epoch 55/1000: [MSE: 0.0905], [KL: 0.3596], [Val_MSE: 0.0827], [Val_KL: 0.3607],
# EarlyStopping counter: 3 out of 10
# Epoch 56/1000: [MSE: 0.0935], [KL: 0.3593], [Val_MSE: 0.0822], [Val_KL: 0.3615],
# EarlyStopping counter: 4 out of 10
# Epoch 57/1000: [MSE: 0.0913], [KL: 0.3597], [Val_MSE: 0.0872], [Val_KL: 0.3601],
# EarlyStopping counter: 5 out of 10
# Epoch 58/1000: [MSE: 0.0906], [KL: 0.3597], [Val_MSE: 0.0839], [Val_KL: 0.3610],
# EarlyStopping counter: 6 out of 10
# Epoch 59/1000: [MSE: 0.0909], [KL: 0.3597], [Val_MSE: 0.0863], [Val_KL: 0.3606],
# EarlyStopping counter: 7 out of 10
# Epoch 60/1000: [MSE: 0.0915], [KL: 0.3598], [Val_MSE: 0.0881], [Val_KL: 0.3598],
# EarlyStopping counter: 8 out of 10
# Epoch 61/1000: [MSE: 0.0877], [KL: 0.3597], [Val_MSE: 0.0808], [Val_KL: 0.3615],
# Validation loss decreased (0.080972 --> 0.080831).  Saving model ...
# Epoch 62/1000: [MSE: 0.0890], [KL: 0.3596], [Val_MSE: 0.0832], [Val_KL: 0.3605],
# EarlyStopping counter: 1 out of 10
# Epoch 63/1000: [MSE: 0.0911], [KL: 0.3594], [Val_MSE: 0.0878], [Val_KL: 0.3598],
# EarlyStopping counter: 2 out of 10
# Epoch 64/1000: [MSE: 0.0915], [KL: 0.3595], [Val_MSE: 0.0825], [Val_KL: 0.3609],
# EarlyStopping counter: 3 out of 10
# Epoch 65/1000: [MSE: 0.0911], [KL: 0.3596], [Val_MSE: 0.0824], [Val_KL: 0.3614],
# EarlyStopping counter: 4 out of 10
# Epoch 66/1000: [MSE: 0.0928], [KL: 0.3597], [Val_MSE: 0.0834], [Val_KL: 0.3604],
# EarlyStopping counter: 5 out of 10
# Epoch 67/1000: [MSE: 0.0942], [KL: 0.3596], [Val_MSE: 0.0823], [Val_KL: 0.3610],
# EarlyStopping counter: 6 out of 10
# Epoch 68/1000: [MSE: 0.0935], [KL: 0.3595], [Val_MSE: 0.0811], [Val_KL: 0.3614],
# EarlyStopping counter: 7 out of 10
# Epoch 69/1000: [MSE: 0.0906], [KL: 0.3596], [Val_MSE: 0.0863], [Val_KL: 0.3602],
# EarlyStopping counter: 8 out of 10
# Epoch 70/1000: [MSE: 0.0921], [KL: 0.3596], [Val_MSE: 0.0818], [Val_KL: 0.3609],
# EarlyStopping counter: 9 out of 10
# Epoch 71/1000: [MSE: 0.0919], [KL: 0.3596], [Val_MSE: 0.0817], [Val_KL: 0.3617],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, kl, val_mse, val_kl):
    fig, axs = plt.subplots(2, figsize=(8,12))
    axs[0].plot(mse, color='r', label='Training')
    axs[0].plot(val_mse, color='b', label='Validation')
    axs[0].set_title('MSE Loss')
    axs[1].plot(kl, color='r', label='Training')
    axs[1].plot(val_kl, color='b', label='Validation')
    axs[1].set_title('KL Loss')
    plt.legend()
    #plt.savefig('./imgMix/mse-kl-mvae.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, kl, val_mse, val_kl)

# %%
vae.eval()
Z = torch.tensor(Z, dtype=torch.float32)
Z_enc = vae(Z)

# %%
idx = 1001
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z[idx,:].cpu().detach().numpy()), label='Original')
axs.plot(np.transpose(Z_enc[idx,:].cpu().detach().numpy()), label='Reconstructed')
axs.set_title('Original vs. Reconstructed Signals')
plt.legend()
plt.show()

# %%
vae.eval()
Z_latent = vae.encoder(Z)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(Z_latent.cpu().detach().numpy()))
axs[0].set_title('Latent Noisy Sensor Signal')
axs[1].plot(np.transpose(Z_enc.cpu().detach().numpy()))
axs[1].set_title('Recunstructed Noisy Sensor Signal')
axs[2].plot(np.transpose(Z.cpu().detach().numpy()))
axs[2].set_title('Original Noisy Sensor Signal')
plt.show()

# %% [markdown]
# **$t=1$ latent distribution**

# %%
vae.eval()
sample_size = 30
signal = Z[0:2]
signal_latent, signal_rec = [], []
for _ in range(sample_size):
    signal_rec.append(vae(signal))
    signal_latent.append(vae.encoder(signal))
signal_latent = torch.stack(signal_latent, dim=0)
signal_rec = torch.stack(signal_rec, dim=0)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(signal_latent.cpu().detach().numpy()[:,0,:]))
axs[0].set_title('Latent Sensor Signal')
axs[1].plot(np.transpose(signal_rec.cpu().detach().numpy()[:,0,:]))
axs[1].set_title('Recunstructed Sensor Signal')
axs[2].plot(np.transpose(signal.cpu().detach().numpy()[0]))
axs[2].set_title('Original Sensor Signal')
plt.show()

# %%
noise_type = 7
noise_percent = 0.2

# %%
import re
import os
import random
import numpy as np
from tqdm import tqdm
from scipy.io import loadmat
import matplotlib.pyplot as plt

import torch
from torchinfo import summary
from torch.utils.data import DataLoader

from models.vae_trainer import VAETrainer

# %%
DATASET_PATH = os.path.join(os.getcwd(), 'data')

# %%
seed = 37
torch.manual_seed(seed)

# %%
class SensorDataset():
    def __init__(self, data: np.array):
        self.x = self.np2tensor(data)
        
    @staticmethod
    def np2tensor(x):
        return torch.tensor(x, dtype=torch.float32)
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx]

# %%
latent_dims = 118
batch_size = 16
epochs = 1000

# %%
data_filename = 'data.mat'
data = loadmat(os.path.join(DATASET_PATH, data_filename))
Z = data['Z']
T = len(Z)
train_size = int(T * 0.8)
lr = 1e-1
scheduler = True
es_patience = 10

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Original Sensor Signal')
plt.show()

# %%
noise_size = int(T * noise_percent)
norm_operation_win = 50

# %%
# read attack noise
NOISE_PATH = os.path.join(DATASET_PATH, f'I{noise_type}')
Z_noise = dict()
for filename in tqdm(os.listdir(NOISE_PATH), desc='Reading noise data ... '):
    fname = os.path.join(NOISE_PATH, filename)
    data = loadmat(fname)
    att_type = int(re.findall(r'\d+', filename)[0])
    Z_noise[att_type] = np.array(data['Z'])

Z_noise = dict(sorted(Z_noise.items()))
# Out:
# Reading noise data ... : 100%|██████████| 3/3 [00:00<00:00,  6.67it/s]

# %%
# sample random times after norm_operation_win to add in Z
noise_time = np.random.choice(list(range(norm_operation_win, T)), size=noise_size, replace=False)
# sample attack types to sample a noise
noise_to_add_from = np.random.choice(list(Z_noise.keys()), size=noise_size, replace=True).tolist()
random.shuffle(noise_to_add_from)
# randomly select noises from attack types
noises = []
for type in noise_to_add_from:
    noise_id = random.sample(range(T), 1)
    noises.append(Z_noise[type][noise_id])
random.shuffle(noises)
noises = np.concatenate(noises, axis=0)
# add noises to original sensor data Z
Z[noise_time] = noises

# %%
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z))
axs.set_title('Noisy Sensor Signal')
plt.show()

# %%
Z_train, Z_test = Z[:train_size], Z[train_size:]
training = SensorDataset(Z_train)
test = SensorDataset(Z_test)
train_dl = DataLoader(training, batch_size=batch_size, shuffle=True)
test_dl = DataLoader(test)

# %%
trainer = VAETrainer(latent_dim=latent_dims, lr=lr, 
                     lr_scheduler=scheduler, es_patience=es_patience,
                     checkpoint_name='vae_20%.pt', seed=seed)
# Out:
# Device:  cpu

# %%
summary(trainer.vae, (1, 358))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VAE                                      [1, 358]                  --
# ├─VariationalEncoder: 1-1                [1, 118]                  --
# │    └─Linear: 2-1                       [1, 236]                  84,724
# │    └─BatchNorm1d: 2-2                  [1, 236]                  472
# │    └─Linear: 2-3                       [1, 118]                  27,966
# │    └─Linear: 2-4                       [1, 118]                  14,042
# │    └─Linear: 2-5                       [1, 118]                  14,042
# ├─Decoder: 1-2                           [1, 358]                  --
# │    └─Linear: 2-6                       [1, 236]                  28,084
# │    └─BatchNorm1d: 2-7                  [1, 236]                  472
# │    └─Linear: 2-8                       [1, 358]                  84,846
# ==========================================================================================
# Total params: 254,648
# Trainable params: 254,648
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.25
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ==========================================================================================

# %%
vae, mse, kl, val_mse, val_kl = trainer.train(train_dl, test_dl, epochs=epochs)
# Out:
# Epoch 1/1000: [MSE: 1.7898], [KL: 1.1983], [Val_MSE: 0.1353], [Val_KL: 0.3636],
# Validation loss decreased (inf --> 0.135323).  Saving model ...
# Epoch 2/1000: [MSE: 0.1115], [KL: 0.3641], [Val_MSE: 0.1054], [Val_KL: 0.3669],
# Validation loss decreased (0.135323 --> 0.105435).  Saving model ...
# Epoch 3/1000: [MSE: 0.1119], [KL: 0.3636], [Val_MSE: 0.1077], [Val_KL: 0.3663],
# EarlyStopping counter: 1 out of 10
# Epoch 4/1000: [MSE: 0.1139], [KL: 0.3621], [Val_MSE: 0.1107], [Val_KL: 0.3701],
# EarlyStopping counter: 2 out of 10
# Epoch 5/1000: [MSE: 0.1094], [KL: 0.3645], [Val_MSE: 0.0991], [Val_KL: 0.3634],
# Validation loss decreased (0.105435 --> 0.099118).  Saving model ...
# Epoch 6/1000: [MSE: 0.1043], [KL: 0.3601], [Val_MSE: 0.1103], [Val_KL: 0.3609],
# EarlyStopping counter: 1 out of 10
# Epoch 7/1000: [MSE: 0.1006], [KL: 0.3600], [Val_MSE: 0.0897], [Val_KL: 0.3606],
# Validation loss decreased (0.099118 --> 0.089749).  Saving model ...
# Epoch 8/1000: [MSE: 0.1030], [KL: 0.3598], [Val_MSE: 0.0851], [Val_KL: 0.3612],
# Validation loss decreased (0.089749 --> 0.085122).  Saving model ...
# Epoch 9/1000: [MSE: 0.1081], [KL: 0.3595], [Val_MSE: 0.1141], [Val_KL: 0.3609],
# EarlyStopping counter: 1 out of 10
# Epoch 10/1000: [MSE: 0.1042], [KL: 0.3597], [Val_MSE: 0.0830], [Val_KL: 0.3656],
# Validation loss decreased (0.085122 --> 0.082956).  Saving model ...
# Epoch 11/1000: [MSE: 0.1071], [KL: 0.3595], [Val_MSE: 0.0953], [Val_KL: 0.3592],
# EarlyStopping counter: 1 out of 10
# Epoch 12/1000: [MSE: 0.1079], [KL: 0.3594], [Val_MSE: 0.0934], [Val_KL: 0.3610],
# EarlyStopping counter: 2 out of 10
# Epoch 13/1000: [MSE: 0.1077], [KL: 0.3597], [Val_MSE: 0.0943], [Val_KL: 0.3616],
# EarlyStopping counter: 3 out of 10
# Epoch 14/1000: [MSE: 0.1051], [KL: 0.3598], [Val_MSE: 0.0904], [Val_KL: 0.3662],
# EarlyStopping counter: 4 out of 10
# Epoch 15/1000: [MSE: 0.1101], [KL: 0.3599], [Val_MSE: 0.0927], [Val_KL: 0.3599],
# EarlyStopping counter: 5 out of 10
# Epoch 16/1000: [MSE: 0.1031], [KL: 0.3598], [Val_MSE: 0.0939], [Val_KL: 0.3605],
# EarlyStopping counter: 6 out of 10
# Epoch 17/1000: [MSE: 0.1044], [KL: 0.3597], [Val_MSE: 0.0820], [Val_KL: 0.3637],
# Validation loss decreased (0.082956 --> 0.082024).  Saving model ...
# Epoch 18/1000: [MSE: 0.1017], [KL: 0.3601], [Val_MSE: 0.0808], [Val_KL: 0.3635],
# Validation loss decreased (0.082024 --> 0.080764).  Saving model ...
# Epoch 19/1000: [MSE: 0.1097], [KL: 0.3597], [Val_MSE: 0.0900], [Val_KL: 0.3669],
# EarlyStopping counter: 1 out of 10
# Epoch 20/1000: [MSE: 0.1015], [KL: 0.3595], [Val_MSE: 0.0987], [Val_KL: 0.3618],
# EarlyStopping counter: 2 out of 10
# Epoch 21/1000: [MSE: 0.1061], [KL: 0.3599], [Val_MSE: 0.1186], [Val_KL: 0.3588],
# EarlyStopping counter: 3 out of 10
# Epoch 22/1000: [MSE: 0.1079], [KL: 0.3595], [Val_MSE: 0.0846], [Val_KL: 0.3634],
# EarlyStopping counter: 4 out of 10
# Epoch 23/1000: [MSE: 0.1047], [KL: 0.3595], [Val_MSE: 0.0874], [Val_KL: 0.3615],
# EarlyStopping counter: 5 out of 10
# Epoch 24/1000: [MSE: 0.1028], [KL: 0.3597], [Val_MSE: 0.0894], [Val_KL: 0.3610],
# EarlyStopping counter: 6 out of 10
# Epoch 25/1000: [MSE: 0.1028], [KL: 0.3594], [Val_MSE: 0.0997], [Val_KL: 0.3616],
# EarlyStopping counter: 7 out of 10
# Epoch 26/1000: [MSE: 0.0956], [KL: 0.3588], [Val_MSE: 0.0839], [Val_KL: 0.3601],
# EarlyStopping counter: 8 out of 10
# Epoch 27/1000: [MSE: 0.0928], [KL: 0.3583], [Val_MSE: 0.0799], [Val_KL: 0.3589],
# Validation loss decreased (0.080764 --> 0.079902).  Saving model ...
# Epoch 28/1000: [MSE: 0.0918], [KL: 0.3586], [Val_MSE: 0.0754], [Val_KL: 0.3607],
# Validation loss decreased (0.079902 --> 0.075429).  Saving model ...
# Epoch 29/1000: [MSE: 0.0925], [KL: 0.3583], [Val_MSE: 0.0747], [Val_KL: 0.3606],
# Validation loss decreased (0.075429 --> 0.074694).  Saving model ...
# Epoch 30/1000: [MSE: 0.0943], [KL: 0.3579], [Val_MSE: 0.0791], [Val_KL: 0.3583],
# EarlyStopping counter: 1 out of 10
# Epoch 31/1000: [MSE: 0.0952], [KL: 0.3580], [Val_MSE: 0.0844], [Val_KL: 0.3580],
# EarlyStopping counter: 2 out of 10
# Epoch 32/1000: [MSE: 0.0902], [KL: 0.3582], [Val_MSE: 0.0760], [Val_KL: 0.3600],
# EarlyStopping counter: 3 out of 10
# Epoch 33/1000: [MSE: 0.0941], [KL: 0.3579], [Val_MSE: 0.0781], [Val_KL: 0.3608],
# EarlyStopping counter: 4 out of 10
# Epoch 34/1000: [MSE: 0.0931], [KL: 0.3579], [Val_MSE: 0.0884], [Val_KL: 0.3572],
# EarlyStopping counter: 5 out of 10
# Epoch 35/1000: [MSE: 0.0936], [KL: 0.3585], [Val_MSE: 0.0818], [Val_KL: 0.3596],
# EarlyStopping counter: 6 out of 10
# Epoch 36/1000: [MSE: 0.0935], [KL: 0.3579], [Val_MSE: 0.0754], [Val_KL: 0.3601],
# EarlyStopping counter: 7 out of 10
# Epoch 37/1000: [MSE: 0.0912], [KL: 0.3581], [Val_MSE: 0.0771], [Val_KL: 0.3581],
# EarlyStopping counter: 8 out of 10
# Epoch 38/1000: [MSE: 0.0894], [KL: 0.3579], [Val_MSE: 0.0771], [Val_KL: 0.3588],
# EarlyStopping counter: 9 out of 10
# Epoch 39/1000: [MSE: 0.0872], [KL: 0.3578], [Val_MSE: 0.0793], [Val_KL: 0.3575],
# EarlyStopping counter: 10 out of 10
# Early stopping!

# %%
def plot_learning(mse, kl, val_mse, val_kl):
    fig, axs = plt.subplots(2, figsize=(8,12))
    axs[0].plot(mse, color='r', label='Training')
    axs[0].plot(val_mse, color='b', label='Validation')
    axs[0].set_title('MSE Loss')
    axs[1].plot(kl, color='r', label='Training')
    axs[1].plot(val_kl, color='b', label='Validation')
    axs[1].set_title('KL Loss')
    plt.legend()
    #plt.savefig('./imgMix/mse-kl-mvae.pdf', format='pdf', dpi=1200)
    plt.show()

# %%
plot_learning(mse, kl, val_mse, val_kl)

# %%
vae.eval()
Z = torch.tensor(Z, dtype=torch.float32)
Z_enc = vae(Z)

# %%
idx = 1001
fig, axs = plt.subplots(figsize=(8,4))
axs.plot(np.transpose(Z[idx,:].cpu().detach().numpy()), label='Original')
axs.plot(np.transpose(Z_enc[idx,:].cpu().detach().numpy()), label='Reconstructed')
axs.set_title('Original vs. Reconstructed Signals')
plt.legend()
plt.show()

# %%
vae.eval()
Z_latent = vae.encoder(Z)

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,10))
axs[0].plot(np.transpose(Z_latent.cpu().detach().numpy()))
axs[0].set_title('Latent Noisy Sensor Signal')
axs[1].plot(np.transpose(Z_enc.cpu().detach().numpy()))
axs[1].set_title('Recunstructed Noisy Sensor Signal')
axs[2].plot(np.transpose(Z.cpu().detach().numpy()))
axs[2].set_title('Original Noisy Sensor Signal')
plt.show()
